# %%
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB = True
except:
    COLAB = False

# !pip install gymnasium==0.29.1 vizdoom==1.2.4 wandb==0.19.1
# Out:
# Collecting gymnasium==0.29.1
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting vizdoom==1.2.4
#   Downloading vizdoom-1.2.4-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting wandb==0.19.1
#   Downloading wandb-0.19.1-py3-none-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gymnasium==0.29.1) (2.3.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gymnasium==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gymnasium==0.29.1) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gymnasium==0.29.1) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from vizdoom==1.2.4) (2.6.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from wandb==0.19.1) (8.2.1)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.19.1)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb==0.19.1)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from wandb==0.19.1) (4.3.8)
# Collecting protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 (from wandb==0.19.1)
#   Downloading protobuf-5.29.5-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from wandb==0.19.1) (7.0.0)
# Collecting pydantic<3,>=2.6 (from wandb==0.19.1)
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
#      ---------------------------------------- 0.0/87.7 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/87.7 kB ? eta -:--:--
#      ------------- ------------------------ 30.7/87.7 kB 640.0 kB/s eta 0:00:01
#      ------------- ------------------------ 30.7/87.7 kB 640.0 kB/s eta 0:00:01
#      -------------------------- ----------- 61.4/87.7 kB 363.1 kB/s eta 0:00:01
#      -------------------------------------- 87.7/87.7 kB 411.8 kB/s eta 0:00:00
# Collecting pyyaml (from wandb==0.19.1)
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Collecting requests<3,>=2.0.0 (from wandb==0.19.1)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb==0.19.1)
#   Downloading sentry_sdk-2.43.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting setproctitle (from wandb==0.19.1)
#   Downloading setproctitle-1.3.7-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from wandb==0.19.1) (65.5.0)
# Requirement already satisfied: colorama in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click!=8.0.0,>=7.1->wandb==0.19.1) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\skfim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from docker-pycreds>=0.4.0->wandb==0.19.1) (1.17.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb==0.19.1)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.6->wandb==0.19.1)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic<3,>=2.6->wandb==0.19.1)
#   Downloading pydantic_core-2.41.4-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium==0.29.1)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=2.6->wandb==0.19.1)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.0.0->wandb==0.19.1)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.0.0->wandb==0.19.1)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.0.0->wandb==0.19.1)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.0.0->wandb==0.19.1)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.19.1)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 10.2/953.9 kB ? eta -:--:--
#    ---------------------------------------- 10.2/953.9 kB ? eta -:--:--
#    - ------------------------------------- 30.7/953.9 kB 217.9 kB/s eta 0:00:05
#    - ------------------------------------- 30.7/953.9 kB 217.9 kB/s eta 0:00:05
#    - ------------------------------------- 41.0/953.9 kB 178.6 kB/s eta 0:00:06
#    -- ------------------------------------ 61.4/953.9 kB 218.8 kB/s eta 0:00:05
#    -- ------------------------------------ 71.7/953.9 kB 206.9 kB/s eta 0:00:05
#    -- ------------------------------------ 71.7/953.9 kB 206.9 kB/s eta 0:00:05
#    --- ----------------------------------- 92.2/953.9 kB 238.1 kB/s eta 0:00:04
#    ---- --------------------------------- 112.6/953.9 kB 261.9 kB/s eta 0:00:04
#    ---- --------------------------------- 122.9/953.9 kB 257.2 kB/s eta 0:00:04
#    ------ ------------------------------- 153.6/953.9 kB 277.8 kB/s eta 0:00:03
#    ------ ------------------------------- 174.1/953.9 kB 291.0 kB/s eta 0:00:03
#    -------- ----------------------------- 204.8/953.9 kB 319.5 kB/s eta 0:00:03
#    -------- ----------------------------- 225.3/953.9 kB 335.5 kB/s eta 0:00:03
#    ---------- --------------------------- 256.0/953.9 kB 349.6 kB/s eta 0:00:02
#    ----------- -------------------------- 286.7/953.9 kB 368.6 kB/s eta 0:00:02
#    ------------ ------------------------- 317.4/953.9 kB 393.3 kB/s eta 0:00:02
#    -------------- ----------------------- 368.6/953.9 kB 424.6 kB/s eta 0:00:02
#    ---------------- --------------------- 419.8/953.9 kB 459.7 kB/s eta 0:00:02
#    ----------------- -------------------- 450.6/953.9 kB 469.4 kB/s eta 0:00:02
#    ------------------- ------------------ 501.8/953.9 kB 499.5 kB/s eta 0:00:01
#    ---------------------- --------------- 553.0/953.9 kB 526.4 kB/s eta 0:00:01
#    ------------------------ ------------- 604.2/953.9 kB 550.9 kB/s eta 0:00:01
#    -------------------------- ----------- 665.6/953.9 kB 582.5 kB/s eta 0:00:01
#    ---------------------------- --------- 727.0/953.9 kB 611.6 kB/s eta 0:00:01
#    ------------------------------- ------ 778.2/953.9 kB 638.4 kB/s eta 0:00:01
#    --------------------------------- ---- 849.9/953.9 kB 671.7 kB/s eta 0:00:01
#    ------------------------------------ - 911.4/953.9 kB 694.8 kB/s eta 0:00:01
#    -------------------------------------  942.1/953.9 kB 701.7 kB/s eta 0:00:01
#    -------------------------------------- 953.9/953.9 kB 678.4 kB/s eta 0:00:00
# Downloading vizdoom-1.2.4-cp311-cp311-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 1.9 MB/s eta 0:00:09
#    ---------------------------------------- 0.2/15.5 MB 1.8 MB/s eta 0:00:09
#     --------------------------------------- 0.2/15.5 MB 1.6 MB/s eta 0:00:10
#     --------------------------------------- 0.3/15.5 MB 1.7 MB/s eta 0:00:10
#     --------------------------------------- 0.4/15.5 MB 1.7 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/15.5 MB 1.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/15.5 MB 1.5 MB/s eta 0:00:10
#    - -------------------------------------- 0.6/15.5 MB 1.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.6/15.5 MB 1.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.7/15.5 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/15.5 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 0.9/15.5 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 1.0/15.5 MB 1.6 MB/s eta 0:00:09
#    -- ------------------------------------- 1.1/15.5 MB 1.7 MB/s eta 0:00:09
#    -- ------------------------------------- 1.1/15.5 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.2/15.5 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.3/15.5 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.4/15.5 MB 1.7 MB/s eta 0:00:09
#    --- ------------------------------------ 1.5/15.5 MB 1.7 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/15.5 MB 1.7 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.7/15.5 MB 1.8 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.8/15.5 MB 1.8 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.9/15.5 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.0/15.5 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.1/15.5 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.2/15.5 MB 1.8 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.3/15.5 MB 1.8 MB/s eta 0:00:08
#    ------ --------------------------------- 2.4/15.5 MB 1.9 MB/s eta 0:00:08
#    ------ --------------------------------- 2.5/15.5 MB 1.9 MB/s eta 0:00:07
#    ------ --------------------------------- 2.6/15.5 MB 1.9 MB/s eta 0:00:07
#    ------ --------------------------------- 2.7/15.5 MB 1.9 MB/s eta 0:00:07
#    ------- -------------------------------- 2.7/15.5 MB 1.9 MB/s eta 0:00:07
#    ------- -------------------------------- 2.9/15.5 MB 1.9 MB/s eta 0:00:07
#    ------- -------------------------------- 3.0/15.5 MB 1.9 MB/s eta 0:00:07
#    ------- -------------------------------- 3.0/15.5 MB 1.9 MB/s eta 0:00:07
#    ------- -------------------------------- 3.1/15.5 MB 1.9 MB/s eta 0:00:07
#    -------- ------------------------------- 3.2/15.5 MB 1.9 MB/s eta 0:00:07
#    -------- ------------------------------- 3.3/15.5 MB 1.9 MB/s eta 0:00:07
#    -------- ------------------------------- 3.5/15.5 MB 1.9 MB/s eta 0:00:07
#    --------- ------------------------------ 3.6/15.5 MB 1.9 MB/s eta 0:00:07
#    --------- ------------------------------ 3.7/15.5 MB 2.0 MB/s eta 0:00:06
#    --------- ------------------------------ 3.7/15.5 MB 2.0 MB/s eta 0:00:06
#    --------- ------------------------------ 3.9/15.5 MB 2.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.9/15.5 MB 2.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.9/15.5 MB 2.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.9/15.5 MB 2.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.9/15.5 MB 2.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.3/15.5 MB 2.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.4/15.5 MB 2.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.5/15.5 MB 2.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.5/15.5 MB 1.9 MB/s eta 0:00:06
#    ------------ --------------------------- 4.7/15.5 MB 2.0 MB/s eta 0:00:06
#    ------------ --------------------------- 4.8/15.5 MB 2.0 MB/s eta 0:00:06
#    ------------ --------------------------- 4.9/15.5 MB 2.0 MB/s eta 0:00:06
#    ------------ --------------------------- 5.0/15.5 MB 2.0 MB/s eta 0:00:06
#    ------------- -------------------------- 5.1/15.5 MB 2.0 MB/s eta 0:00:06
#    ------------- -------------------------- 5.2/15.5 MB 2.0 MB/s eta 0:00:06
#    ------------- -------------------------- 5.3/15.5 MB 2.0 MB/s eta 0:00:06
#    ------------- -------------------------- 5.4/15.5 MB 2.0 MB/s eta 0:00:06
#    ------------- -------------------------- 5.4/15.5 MB 2.0 MB/s eta 0:00:06
#    -------------- ------------------------- 5.5/15.5 MB 2.0 MB/s eta 0:00:06
#    -------------- ------------------------- 5.6/15.5 MB 2.0 MB/s eta 0:00:05
#    -------------- ------------------------- 5.7/15.5 MB 2.0 MB/s eta 0:00:05
#    -------------- ------------------------- 5.8/15.5 MB 2.0 MB/s eta 0:00:05
#    --------------- ------------------------ 5.9/15.5 MB 2.0 MB/s eta 0:00:05
#    --------------- ------------------------ 6.0/15.5 MB 2.0 MB/s eta 0:00:05
#    --------------- ------------------------ 6.0/15.5 MB 2.0 MB/s eta 0:00:05
#    --------------- ------------------------ 6.1/15.5 MB 2.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.2/15.5 MB 2.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.3/15.5 MB 2.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.3/15.5 MB 2.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.5/15.5 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.6/15.5 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.6/15.5 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.8/15.5 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.9/15.5 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.9/15.5 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.0/15.5 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.1/15.5 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.2/15.5 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.3/15.5 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.4/15.5 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.5/15.5 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.6/15.5 MB 2.0 MB/s eta 0:00:04
#    ------------------- -------------------- 7.6/15.5 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 7.8/15.5 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 7.9/15.5 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 7.9/15.5 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 8.0/15.5 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 8.1/15.5 MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 8.3/15.5 MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 8.3/15.5 MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 8.4/15.5 MB 2.0 MB/s eta 0:00:04
#    --------------------- ------------------ 8.5/15.5 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.6/15.5 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.7/15.5 MB 2.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.8/15.5 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 8.9/15.5 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.0/15.5 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.1/15.5 MB 2.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.2/15.5 MB 2.0 MB/s eta 0:00:04
#    ------------------------ --------------- 9.3/15.5 MB 2.0 MB/s eta 0:00:04
#    ------------------------ --------------- 9.3/15.5 MB 2.0 MB/s eta 0:00:04
#    ------------------------ --------------- 9.5/15.5 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 9.6/15.5 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 9.7/15.5 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 9.8/15.5 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 9.9/15.5 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 10.0/15.5 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 10.1/15.5 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 10.2/15.5 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 10.3/15.5 MB 2.0 MB/s eta 0:00:03
#    -------------------------- ------------- 10.4/15.5 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 10.5/15.5 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 10.6/15.5 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 10.7/15.5 MB 2.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.9/15.5 MB 2.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.9/15.5 MB 2.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.0/15.5 MB 2.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.2/15.5 MB 2.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.2/15.5 MB 2.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.3/15.5 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.4/15.5 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.6/15.5 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.6/15.5 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 11.7/15.5 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 11.8/15.5 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 12.0/15.5 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 12.0/15.5 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 12.1/15.5 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 12.3/15.5 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 12.4/15.5 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 12.5/15.5 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 12.6/15.5 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 12.7/15.5 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 12.7/15.5 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 12.9/15.5 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 13.1/15.5 MB 2.1 MB/s eta 0:00:02
#    --------------------------------- ------ 13.1/15.5 MB 2.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.2/15.5 MB 2.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.3/15.5 MB 2.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.5/15.5 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.7/15.5 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.8/15.5 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.5 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 13.9/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 13.9/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 13.9/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.0/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.0/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.0/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.1/15.5 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.3/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.3/15.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.5 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.5 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 14.5/15.5 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  15.3/15.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 2.0 MB/s eta 0:00:00
# Downloading wandb-0.19.1-py3-none-win_amd64.whl (19.5 MB)
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/19.5 MB 4.3 MB/s eta 0:00:05
#     --------------------------------------- 0.3/19.5 MB 3.5 MB/s eta 0:00:06
#     --------------------------------------- 0.4/19.5 MB 3.3 MB/s eta 0:00:06
#     --------------------------------------- 0.4/19.5 MB 2.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.6/19.5 MB 2.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.7/19.5 MB 2.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.8/19.5 MB 2.7 MB/s eta 0:00:08
#    - -------------------------------------- 0.8/19.5 MB 2.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.9/19.5 MB 2.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.1/19.5 MB 2.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.1/19.5 MB 2.4 MB/s eta 0:00:08
#    -- ------------------------------------- 1.3/19.5 MB 2.3 MB/s eta 0:00:08
#    -- ------------------------------------- 1.4/19.5 MB 2.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.5/19.5 MB 2.4 MB/s eta 0:00:08
#    --- ------------------------------------ 1.5/19.5 MB 2.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.6/19.5 MB 2.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.7/19.5 MB 2.2 MB/s eta 0:00:09
#    --- ------------------------------------ 1.8/19.5 MB 2.2 MB/s eta 0:00:08
#    --- ------------------------------------ 1.9/19.5 MB 2.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.0/19.5 MB 2.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.1/19.5 MB 2.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.3/19.5 MB 2.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.3/19.5 MB 2.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.5/19.5 MB 2.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.6/19.5 MB 2.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.7/19.5 MB 2.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.7/19.5 MB 2.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.9/19.5 MB 2.3 MB/s eta 0:00:08
#    ------ --------------------------------- 3.0/19.5 MB 2.3 MB/s eta 0:00:08
#    ------ --------------------------------- 3.1/19.5 MB 2.3 MB/s eta 0:00:08
#    ------ --------------------------------- 3.1/19.5 MB 2.2 MB/s eta 0:00:08
#    ------ --------------------------------- 3.3/19.5 MB 2.3 MB/s eta 0:00:08
#    ------- -------------------------------- 3.4/19.5 MB 2.3 MB/s eta 0:00:08
#    ------- -------------------------------- 3.5/19.5 MB 2.3 MB/s eta 0:00:08
#    ------- -------------------------------- 3.5/19.5 MB 2.2 MB/s eta 0:00:08
#    ------- -------------------------------- 3.6/19.5 MB 2.2 MB/s eta 0:00:08
#    ------- -------------------------------- 3.8/19.5 MB 2.3 MB/s eta 0:00:07
#    ------- -------------------------------- 3.8/19.5 MB 2.3 MB/s eta 0:00:07
#    -------- ------------------------------- 3.9/19.5 MB 2.2 MB/s eta 0:00:08
#    -------- ------------------------------- 4.1/19.5 MB 2.2 MB/s eta 0:00:07
#    -------- ------------------------------- 4.2/19.5 MB 2.3 MB/s eta 0:00:07
#    -------- ------------------------------- 4.2/19.5 MB 2.3 MB/s eta 0:00:07
#    -------- ------------------------------- 4.4/19.5 MB 2.2 MB/s eta 0:00:07
#    --------- ------------------------------ 4.5/19.5 MB 2.2 MB/s eta 0:00:07
#    --------- ------------------------------ 4.6/19.5 MB 2.3 MB/s eta 0:00:07
#    --------- ------------------------------ 4.6/19.5 MB 2.2 MB/s eta 0:00:07
#    --------- ------------------------------ 4.8/19.5 MB 2.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 4.9/19.5 MB 2.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 5.0/19.5 MB 2.3 MB/s eta 0:00:07
#    ---------- ----------------------------- 5.1/19.5 MB 2.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 5.2/19.5 MB 2.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 5.4/19.5 MB 2.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 5.4/19.5 MB 2.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 5.5/19.5 MB 2.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 5.6/19.5 MB 2.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 5.8/19.5 MB 2.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 5.8/19.5 MB 2.2 MB/s eta 0:00:07
#    ------------ --------------------------- 6.0/19.5 MB 2.3 MB/s eta 0:00:06
#    ------------ --------------------------- 6.1/19.5 MB 2.2 MB/s eta 0:00:06
#    ------------ --------------------------- 6.2/19.5 MB 2.3 MB/s eta 0:00:06
#    ------------- -------------------------- 6.3/19.5 MB 2.3 MB/s eta 0:00:06
#    ------------- -------------------------- 6.4/19.5 MB 2.3 MB/s eta 0:00:06
#    ------------- -------------------------- 6.6/19.5 MB 2.3 MB/s eta 0:00:06
#    ------------- -------------------------- 6.6/19.5 MB 2.3 MB/s eta 0:00:06
#    ------------- -------------------------- 6.8/19.5 MB 2.3 MB/s eta 0:00:06
#    -------------- ------------------------- 6.9/19.5 MB 2.3 MB/s eta 0:00:06
#    -------------- ------------------------- 6.9/19.5 MB 2.3 MB/s eta 0:00:06
#    -------------- ------------------------- 6.9/19.5 MB 2.3 MB/s eta 0:00:06
#    -------------- ------------------------- 6.9/19.5 MB 2.3 MB/s eta 0:00:06
#    -------------- ------------------------- 7.2/19.5 MB 2.3 MB/s eta 0:00:06
#    --------------- ------------------------ 7.3/19.5 MB 2.3 MB/s eta 0:00:06
#    --------------- ------------------------ 7.4/19.5 MB 2.3 MB/s eta 0:00:06
#    --------------- ------------------------ 7.5/19.5 MB 2.3 MB/s eta 0:00:06
#    --------------- ------------------------ 7.6/19.5 MB 2.2 MB/s eta 0:00:06
#    --------------- ------------------------ 7.7/19.5 MB 2.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 7.8/19.5 MB 2.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 7.9/19.5 MB 2.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 8.0/19.5 MB 2.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 8.1/19.5 MB 2.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 8.1/19.5 MB 2.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 8.2/19.5 MB 2.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 8.4/19.5 MB 2.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.4/19.5 MB 2.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.5/19.5 MB 2.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.6/19.5 MB 2.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.7/19.5 MB 2.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.7/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------ --------------------- 8.8/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------ --------------------- 9.0/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------ --------------------- 9.0/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------ --------------------- 9.1/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------ --------------------- 9.2/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------- -------------------- 9.3/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------- -------------------- 9.3/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------- -------------------- 9.5/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------- -------------------- 9.6/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------- -------------------- 9.7/19.5 MB 2.2 MB/s eta 0:00:05
#    ------------------- -------------------- 9.7/19.5 MB 2.2 MB/s eta 0:00:05
#    -------------------- ------------------- 9.8/19.5 MB 2.2 MB/s eta 0:00:05
#    -------------------- ------------------- 10.0/19.5 MB 2.2 MB/s eta 0:00:05
#    -------------------- ------------------- 10.0/19.5 MB 2.2 MB/s eta 0:00:05
#    -------------------- ------------------- 10.1/19.5 MB 2.2 MB/s eta 0:00:05
#    -------------------- ------------------- 10.2/19.5 MB 2.2 MB/s eta 0:00:05
#    --------------------- ------------------ 10.3/19.5 MB 2.2 MB/s eta 0:00:05
#    --------------------- ------------------ 10.4/19.5 MB 2.1 MB/s eta 0:00:05
#    --------------------- ------------------ 10.6/19.5 MB 2.2 MB/s eta 0:00:05
#    --------------------- ------------------ 10.7/19.5 MB 2.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 10.8/19.5 MB 2.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 10.9/19.5 MB 2.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 11.0/19.5 MB 2.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 11.1/19.5 MB 2.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.2/19.5 MB 2.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.4/19.5 MB 2.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.4/19.5 MB 2.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.5/19.5 MB 2.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.7/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 11.7/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 11.8/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 11.9/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 12.1/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------ --------------- 12.1/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------- -------------- 12.2/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------- -------------- 12.3/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------- -------------- 12.5/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------- -------------- 12.5/19.5 MB 2.2 MB/s eta 0:00:04
#    ------------------------- -------------- 12.6/19.5 MB 2.2 MB/s eta 0:00:04
#    -------------------------- ------------- 12.7/19.5 MB 2.2 MB/s eta 0:00:04
#    -------------------------- ------------- 12.8/19.5 MB 2.2 MB/s eta 0:00:04
#    -------------------------- ------------- 12.9/19.5 MB 2.2 MB/s eta 0:00:03
#    -------------------------- ------------- 13.0/19.5 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 13.1/19.5 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 13.3/19.5 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 13.4/19.5 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 13.5/19.5 MB 2.2 MB/s eta 0:00:03
#    --------------------------- ------------ 13.6/19.5 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.7/19.5 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.8/19.5 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 13.9/19.5 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 14.1/19.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.2/19.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.3/19.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.5/19.5 MB 2.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 14.6/19.5 MB 2.2 MB/s eta 0:00:03
#    ------------------------------ --------- 14.7/19.5 MB 2.2 MB/s eta 0:00:03
#    ------------------------------ --------- 14.7/19.5 MB 2.2 MB/s eta 0:00:03
#    ------------------------------ --------- 14.9/19.5 MB 2.2 MB/s eta 0:00:03
#    ------------------------------ --------- 15.0/19.5 MB 2.2 MB/s eta 0:00:02
#    ------------------------------ --------- 15.1/19.5 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 15.1/19.5 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 15.3/19.5 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 15.4/19.5 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 15.4/19.5 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 15.5/19.5 MB 2.2 MB/s eta 0:00:02
#    -------------------------------- ------- 15.7/19.5 MB 2.2 MB/s eta 0:00:02
#    -------------------------------- ------- 15.8/19.5 MB 2.2 MB/s eta 0:00:02
#    -------------------------------- ------- 15.8/19.5 MB 2.2 MB/s eta 0:00:02
#    -------------------------------- ------- 15.9/19.5 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 16.1/19.5 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 16.2/19.5 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 16.2/19.5 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 16.4/19.5 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 16.5/19.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.6/19.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.6/19.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.8/19.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.8/19.5 MB 2.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 17.0/19.5 MB 2.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 17.1/19.5 MB 2.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 17.2/19.5 MB 2.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 17.3/19.5 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.4/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 17.5/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 17.6/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 17.7/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 17.8/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 18.0/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 18.0/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 18.2/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 18.4/19.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 18.4/19.5 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 18.5/19.5 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 18.6/19.5 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 18.8/19.5 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 18.8/19.5 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 18.9/19.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  19.2/19.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  19.2/19.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  19.5/19.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  19.5/19.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 19.5/19.5 MB 2.2 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
#    ---------------------------------------- 0.0/208.2 kB ? eta -:--:--
#    --------------------------- ------------ 143.4/208.2 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 208.2/208.2 kB 3.1 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp310-abi3-win_amd64.whl (434 kB)
#    ---------------------------------------- 0.0/434.8 kB ? eta -:--:--
#    -------------- ------------------------- 153.6/434.8 kB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 286.7/434.8 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 378.9/434.8 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 378.9/434.8 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 434.8/434.8 kB 1.8 MB/s eta 0:00:00
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
#    ---------------------------------------- 0.0/462.4 kB ? eta -:--:--
#    ------------ --------------------------- 143.4/462.4 kB 4.3 MB/s eta 0:00:01
#    ------------------------ --------------- 286.7/462.4 kB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 389.1/462.4 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 399.4/462.4 kB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 450.6/462.4 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 462.4/462.4 kB 1.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.4-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.0 MB 3.1 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/2.0 MB 3.2 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.0 MB 2.9 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.0 MB 2.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.0 MB 2.4 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.0 MB 2.4 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 2.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 2.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.0 MB 2.4 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.0 MB 2.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.0 MB 2.5 MB/s eta 0:00:01
#    ------------------------ --------------- 1.2/2.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 2.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 1.9/2.0 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 2.0/2.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.7 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.7 kB ? eta -:--:--
#    ------------------------- -------------- 41.0/64.7 kB ? eta -:--:--
#    ---------------------------------------- 64.7/64.7 kB 698.7 kB/s eta 0:00:00
# Downloading sentry_sdk-2.43.0-py2.py3-none-any.whl (400 kB)
#    ---------------------------------------- 0.0/401.0 kB ? eta -:--:--
#    ----------- ---------------------------- 112.6/401.0 kB 3.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 235.5/401.0 kB 2.9 MB/s eta 0:00:01
#    ------------------------------------ --- 368.6/401.0 kB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 389.1/401.0 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  399.4/401.0 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 401.0/401.0 kB 1.8 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.6 kB ? eta -:--:--
#    --------------------------- ------------ 30.7/44.6 kB ? eta -:--:--
#    ---------------------------------------- 44.6/44.6 kB 545.6 kB/s eta 0:00:00
# Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
#    ---------------------------------------- 0.0/158.8 kB ? eta -:--:--
#    --------------------------------- ------ 133.1/158.8 kB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 158.8/158.8 kB 1.9 MB/s eta 0:00:00
# Downloading setproctitle-1.3.7-cp311-cp311-win_amd64.whl (13 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.3 kB ? eta -:--:--
#    ------------------------------------- -- 153.6/163.3 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 163.3/163.3 kB 2.0 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
#    ---------------------------------------- 0.0/107.0 kB ? eta -:--:--
#    -------------------------------------- - 102.4/107.0 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 107.0/107.0 kB 3.1 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    -------------------------- ------------- 41.0/62.8 kB ? eta -:--:--
#    ---------------------------------------- 62.8/62.8 kB 847.6 kB/s eta 0:00:00
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.0 kB ? eta -:--:--
#    ---------------------------------- ----- 61.4/71.0 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 71.0/71.0 kB 980.1 kB/s eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: urllib3, typing-extensions, smmap, setproctitle, pyyaml, protobuf, idna, docker-pycreds, charset_normalizer, certifi, annotated-types, typing-inspection, sentry-sdk, requests, pydantic-core, gymnasium, gitdb, vizdoom, pydantic, gitpython, wandb
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.14.0
#     Uninstalling typing_extensions-4.14.0:
#       Successfully uninstalled typing_extensions-4.14.0
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.2.1
#     Uninstalling gymnasium-1.2.1:
#       Successfully uninstalled gymnasium-1.2.1
# Successfully installed annotated-types-0.7.0 certifi-2025.10.5 charset_normalizer-3.4.4 docker-pycreds-0.4.0 gitdb-4.0.12 gitpython-3.1.45 gymnasium-0.29.1 idna-3.11 protobuf-5.29.5 pydantic-2.12.3 pydantic-core-2.41.4 pyyaml-6.0.3 requests-2.32.5 sentry-sdk-2.43.0 setproctitle-1.3.7 smmap-5.0.2 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.5.0 vizdoom-1.2.4 wandb-0.19.1
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\skfim\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import json
import math
import random
import sys
import os
import time
from collections import deque
from typing import Dict, Type, Any, Tuple, NamedTuple, Optional, Union, Generator, List

import gymnasium as gym
import gymnasium.spaces as spaces
from gymnasium.vector import AsyncVectorEnv, SyncVectorEnv
from gymnasium.wrappers import ResizeObservation, GrayScaleObservation, RecordEpisodeStatistics, TransformReward, \
    FrameStack
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.distributions import Categorical
import vizdoom
from vizdoom import gymnasium_wrapper

try:
    import wandb
    WANDB_IS_AVAILABLE = True
except ImportError:
    WANDB_IS_AVAILABLE = False

os.environ["WANDB_API_KEY"] = "e97ffa4c776cbfb2c0fc0c8b5c97e875139c1d42"
os.environ["WANDB_MODE"] = "offline"

# %% [markdown]
# # Градиент стратегии: REINFORCE
#
# Обозначения:
# - $s$ - состояние, $r$ - вознаграждение, $a$ - действие
# - Условное распределение действий $\pi(a | s)$ - стратегия агента
# - $\tau$ - траектория: $(s_0, r_0, a_0), \dots, (s_T, r_T, a_T)$
# - Отдача $G(\tau) = \sum_{t = 0} ^ T r_t \gamma ^ t$
# - $G_t = r_t + r_{t + 1} \gamma + \dots + r_{T} \gamma ^ {T - t}$
# - Функция полезности состояний: $V(s_{t}) = \mathbb{E}[G_t]$
# - Функция полезности действий: $Q(s_t, a_t) = \mathbb{E}[r_t + \gamma V(s_{t + 1}) | a_t]$
#
# В некоторых задачах для нахождения удовлетворительной стратегии необязательно в точности знать структуру всей среды. Например, в задаче поднятия кубика робототехнической рукой вместо точной аппроксимации полезности $Q(s,a)$ достаточно знать, что выгоднее: двигаться вправо, если кубик справа, и влево в ином случае. С этим же наблюдением связано и предположение, что задача поиска удовлетворительной стратегии проще, нежели задача точной оценки функции полезности.
#
# В данном семинаре познакомимся с простейшим методом прямой оптимизации стратегии REINFORCE, в котором параметры, задающие вероятностную стратегию, изменяются в соответствии с градиентом математического ожидания отдач:
#
# $$J(\theta)= \mathbb{E}[G(\tau)],$$
#
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
#
# В первом выражении математическое ожидание берется по распределениям начальных состояний, вероятностным функциям переходов и вознаграждений среды, а также по вероятностной стратегии агента $\pi_\theta$. Благодаря теореме о существовании стационарного распределения марковской цепи, это выражение может быть переписано через стационарное распределение $d^\pi$ посещения состояний в среде:
#
# $$J(\theta)= \mathbb{E}_{s \sim d^\pi}[V^{\pi}(s)] = \mathbb{E}_{s \sim d^\pi, a \sim \pi(s)} [Q^{\pi}(s, a)] =: \mathbb{E}_\pi [Q^{\pi}(s, a)].$$
#
# Метод REINFORCE также использует теорему о градиенте стратегии, на основе которой построено целое семейство алгоритмов прямой оптимизации стратегии и актор-критиков. Теорема о градиенте стратегии связывает градиент целевой функции $J$ и градиент самой стратегии:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [Q^\pi(s, a) \nabla_\theta \ln \pi_\theta(a \vert s)]$$
#
# Для оценки полезности действий $Q^\pi(s, a)$ REINFORCE использует несмещенную Монте-Карло оценку на основе полученных в среде отдач $G_t$ (за некоторое фиксированное число эпизодов в среде). С учетом этого обновление весов осуществляется по правилу:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [G_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# Более подробное (но все равно короткое) описание градиента стратегии, и в частности REINFORCE, можно посмотреть в [блоге Lilian Weng из OpenAI](https://lilianweng.github.io/posts/2018-04-08-policy-gradient/#policy-gradient), либо полноценно разобраться в соответствующей секции классического учебника Саттона и Барто.

# %% [markdown]
# ### Environment: Vizdoom
# Среда для экспериментов: **Vizdoom**. Задача: **VizdoomCorridor-v0**.
#
# Карта представляет собой коридор со стреляющими противниками по обеим сторонам. Зелёная броня размещена на противоположном конце коридора. Цель агента — добраться до предмета. Награда пропорциональна (отрицательна или положительна) изменению расстояния между игроком и жилетом.
# - Вознаграждение: +dX за приближение к броне, -dX за отдаление от брони, -100 за смерть.
# - Агенту доступны 7 действий: движение вперед/назад/влево/вправо, поворот влево/вправо, стрельба.
# - Ограничение по времени: 2100 шагов
#
# Для ускорения обучения агента рассматриваем самый простой уровень сложности `doom_skill = 1`.

# %%
def create_vizdoom_config(verbose=False):
    # Создаёт файл сценария VizdoomCorridor с уровнем сложности doom_skill = 1

    deadly_corridor_doom_skill_1 = """
    # Lines starting with # are treated as comments (or with whitespaces+#).
    # It doesn't matter if you use capital letters or not.
    # It doesn't matter if you use underscore or camel notation for keys, e.g. episode_timeout is the same as episodeTimeout.
    """
    deadly_corridor_doom_skill_1 += f"\ndoom_scenario_path = {os.path.relpath(os.path.dirname(vizdoom.__file__))}/scenarios/deadly_corridor.wad\n"
    deadly_corridor_doom_skill_1 += """
    # Skill 5 is recommended for the scenario to be a challenge.
    doom_skill = 1

    # Rewards
    death_penalty = 100
    #living_reward = 0

    # Rendering options
    screen_resolution = RES_320X240
    screen_format = CRCGCB
    render_hud = true
    render_crosshair = false
    render_weapon = true
    render_decals = false
    render_particles = false
    window_visible = true

    episode_timeout = 2100

    # Available buttons
    available_buttons =
      {
        MOVE_LEFT
        MOVE_RIGHT
        ATTACK
        MOVE_FORWARD
        MOVE_BACKWARD
        TURN_LEFT
        TURN_RIGHT
      }

    # Game variables that will be in the state
    available_game_variables = { HEALTH }

    mode = PLAYER
    """

    config_file_name = f'deadly_corridor_doom-skill-1.cfg'
    with open(config_file_name, 'w') as file_obj:
        print(deadly_corridor_doom_skill_1, file=file_obj)

    if verbose:
        print(deadly_corridor_doom_skill_1)

    return os.path.realpath(config_file_name)


def source_env_info():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    obs, _ = env.reset()
    plt.imshow(obs['screen'])
    plt.show()
    print(env.env.env.spec.kwargs)

source_env_info()
# Out:
# C:\Users\skfim\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# {'scenario_file': 'C:\\Users\\skfim\\RL\\RL25\\practices\\prac5\\deadly_corridor_doom-skill-1.cfg'}

# %% [markdown]
# ### Wrappers

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 330.3 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 281.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 361.5 kB/s eta 0:00:00
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB 660.6 kB/s eta 0:00:59
#    ---------------------------------------- 0.1/39.0 MB 544.7 kB/s eta 0:01:12
#    ---------------------------------------- 0.1/39.0 MB 525.1 kB/s eta 0:01:15
#    ---------------------------------------- 0.1/39.0 MB 554.9 kB/s eta 0:01:11
#    ---------------------------------------- 0.1/39.0 MB 607.9 kB/s eta 0:01:04
#    ---------------------------------------- 0.2/39.0 MB 655.9 kB/s eta 0:01:00
#    ---------------------------------------- 0.2/39.0 MB 654.9 kB/s eta 0:01:00
#    ---------------------------------------- 0.3/39.0 MB 707.1 kB/s eta 0:00:55
#    ---------------------------------------- 0.3/39.0 MB 728.0 kB/s eta 0:00:54
#    ---------------------------------------- 0.4/39.0 MB 739.0 kB/s eta 0:00:53
#    ---------------------------------------- 0.4/39.0 MB 793.8 kB/s eta 0:00:49
#    ---------------------------------------- 0.5/39.0 MB 818.5 kB/s eta 0:00:48
#     --------------------------------------- 0.5/39.0 MB 839.3 kB/s eta 0:00:46
#     --------------------------------------- 0.6/39.0 MB 842.9 kB/s eta 0:00:46
#     --------------------------------------- 0.6/39.0 MB 859.4 kB/s eta 0:00:45
#     --------------------------------------- 0.7/39.0 MB 873.8 kB/s eta 0:00:44
#     --------------------------------------- 0.7/39.0 MB 886.5 kB/s eta 0:00:44
#     --------------------------------------- 0.8/39.0 MB 910.0 kB/s eta 0:00:43
#     --------------------------------------- 0.8/39.0 MB 919.4 kB/s eta 0:00:42
#     --------------------------------------- 0.9/39.0 MB 938.8 kB/s eta 0:00:41
#     --------------------------------------- 0.9/39.0 MB 946.0 kB/s eta 0:00:41
#    - -------------------------------------- 1.0/39.0 MB 983.3 kB/s eta 0:00:39
#    - -------------------------------------- 1.1/39.0 MB 1.0 MB/s eta 0:00:38
#    - -------------------------------------- 1.2/39.0 MB 1.0 MB/s eta 0:00:37
#    - -------------------------------------- 1.3/39.0 MB 1.1 MB/s eta 0:00:36
#    - -------------------------------------- 1.4/39.0 MB 1.1 MB/s eta 0:00:34
#    - -------------------------------------- 1.5/39.0 MB 1.2 MB/s eta 0:00:32
#    - -------------------------------------- 1.6/39.0 MB 1.2 MB/s eta 0:00:31
#    - -------------------------------------- 1.7/39.0 MB 1.2 MB/s eta 0:00:31
#    - -------------------------------------- 1.8/39.0 MB 1.3 MB/s eta 0:00:29
#    - -------------------------------------- 1.9/39.0 MB 1.3 MB/s eta 0:00:28
#    -- ------------------------------------- 2.1/39.0 MB 1.4 MB/s eta 0:00:27
#    -- ------------------------------------- 2.2/39.0 MB 1.4 MB/s eta 0:00:27
#    -- ------------------------------------- 2.2/39.0 MB 1.4 MB/s eta 0:00:26
#    -- ------------------------------------- 2.4/39.0 MB 1.4 MB/s eta 0:00:26
#    -- ------------------------------------- 2.5/39.0 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.5/39.0 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.7/39.0 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.8/39.0 MB 1.5 MB/s eta 0:00:24
#    -- ------------------------------------- 2.9/39.0 MB 1.6 MB/s eta 0:00:24
#    --- ------------------------------------ 3.0/39.0 MB 1.6 MB/s eta 0:00:23
#    --- ------------------------------------ 3.1/39.0 MB 1.6 MB/s eta 0:00:23
#    --- ------------------------------------ 3.2/39.0 MB 1.6 MB/s eta 0:00:23
#    --- ------------------------------------ 3.3/39.0 MB 1.6 MB/s eta 0:00:22
#    --- ------------------------------------ 3.5/39.0 MB 1.6 MB/s eta 0:00:22
#    --- ------------------------------------ 3.6/39.0 MB 1.7 MB/s eta 0:00:22
#    --- ------------------------------------ 3.7/39.0 MB 1.7 MB/s eta 0:00:22
#    --- ------------------------------------ 3.8/39.0 MB 1.7 MB/s eta 0:00:21
#    ---- ----------------------------------- 3.9/39.0 MB 1.7 MB/s eta 0:00:21
#    ---- ----------------------------------- 4.0/39.0 MB 1.7 MB/s eta 0:00:21
#    ---- ----------------------------------- 4.2/39.0 MB 1.7 MB/s eta 0:00:20
#    ---- ----------------------------------- 4.3/39.0 MB 1.8 MB/s eta 0:00:20
#    ---- ----------------------------------- 4.4/39.0 MB 1.8 MB/s eta 0:00:20
#    ---- ----------------------------------- 4.5/39.0 MB 1.8 MB/s eta 0:00:20
#    ---- ----------------------------------- 4.6/39.0 MB 1.8 MB/s eta 0:00:20
#    ---- ----------------------------------- 4.8/39.0 MB 1.8 MB/s eta 0:00:19
#    ---- ----------------------------------- 4.8/39.0 MB 1.8 MB/s eta 0:00:19
#    ----- ---------------------------------- 5.0/39.0 MB 1.9 MB/s eta 0:00:19
#    ----- ---------------------------------- 5.2/39.0 MB 1.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 5.2/39.0 MB 1.9 MB/s eta 0:00:19
#    ----- ---------------------------------- 5.4/39.0 MB 1.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 5.5/39.0 MB 1.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 5.5/39.0 MB 1.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 5.5/39.0 MB 1.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 5.6/39.0 MB 1.9 MB/s eta 0:00:18
#    ------ --------------------------------- 6.0/39.0 MB 2.0 MB/s eta 0:00:17
#    ------ --------------------------------- 6.1/39.0 MB 2.0 MB/s eta 0:00:17
#    ------ --------------------------------- 6.2/39.0 MB 2.0 MB/s eta 0:00:17
#    ------ --------------------------------- 6.3/39.0 MB 2.0 MB/s eta 0:00:17
#    ------ --------------------------------- 6.4/39.0 MB 2.0 MB/s eta 0:00:17
#    ------ --------------------------------- 6.5/39.0 MB 2.0 MB/s eta 0:00:17
#    ------ --------------------------------- 6.6/39.0 MB 2.0 MB/s eta 0:00:17
#    ------ --------------------------------- 6.8/39.0 MB 2.0 MB/s eta 0:00:17
#    ------- -------------------------------- 6.9/39.0 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 7.0/39.0 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 7.1/39.0 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 7.2/39.0 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 7.3/39.0 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 7.5/39.0 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 7.5/39.0 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 7.7/39.0 MB 2.1 MB/s eta 0:00:16
#    ------- -------------------------------- 7.8/39.0 MB 2.0 MB/s eta 0:00:16
#    -------- ------------------------------- 7.9/39.0 MB 2.1 MB/s eta 0:00:16
#    -------- ------------------------------- 8.1/39.0 MB 2.1 MB/s eta 0:00:15
#    -------- ------------------------------- 8.1/39.0 MB 2.1 MB/s eta 0:00:15
#    -------- ------------------------------- 8.3/39.0 MB 2.1 MB/s eta 0:00:15
#    -------- ------------------------------- 8.4/39.0 MB 2.1 MB/s eta 0:00:15
#    -------- ------------------------------- 8.5/39.0 MB 2.1 MB/s eta 0:00:15
#    -------- ------------------------------- 8.6/39.0 MB 2.1 MB/s eta 0:00:15
#    -------- ------------------------------- 8.8/39.0 MB 2.1 MB/s eta 0:00:15
#    --------- ------------------------------ 8.8/39.0 MB 2.1 MB/s eta 0:00:15
#    --------- ------------------------------ 8.8/39.0 MB 2.1 MB/s eta 0:00:15
#    --------- ------------------------------ 8.8/39.0 MB 2.1 MB/s eta 0:00:15
#    --------- ------------------------------ 8.8/39.0 MB 2.1 MB/s eta 0:00:15
#    --------- ------------------------------ 8.9/39.0 MB 2.0 MB/s eta 0:00:15
#    --------- ------------------------------ 9.4/39.0 MB 2.1 MB/s eta 0:00:14
#    --------- ------------------------------ 9.5/39.0 MB 2.1 MB/s eta 0:00:14
#    --------- ------------------------------ 9.5/39.0 MB 2.1 MB/s eta 0:00:14
#    --------- ------------------------------ 9.7/39.0 MB 2.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 9.8/39.0 MB 2.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 9.9/39.0 MB 2.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 10.0/39.0 MB 2.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 10.1/39.0 MB 2.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 10.3/39.0 MB 2.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 10.4/39.0 MB 2.2 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.4/39.0 MB 2.2 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.5/39.0 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.6/39.0 MB 2.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 10.7/39.0 MB 2.3 MB/s eta 0:00:13
#    ----------- ---------------------------- 10.8/39.0 MB 2.3 MB/s eta 0:00:13
#    ----------- ---------------------------- 10.9/39.0 MB 2.4 MB/s eta 0:00:12
#    ----------- ---------------------------- 11.0/39.0 MB 2.4 MB/s eta 0:00:12
#    ----------- ---------------------------- 11.1/39.0 MB 2.4 MB/s eta 0:00:12
#    ----------- ---------------------------- 11.2/39.0 MB 2.4 MB/s eta 0:00:12
#    ----------- ---------------------------- 11.3/39.0 MB 2.4 MB/s eta 0:00:12
#    ----------- ---------------------------- 11.4/39.0 MB 2.4 MB/s eta 0:00:12
#    ----------- ---------------------------- 11.6/39.0 MB 2.4 MB/s eta 0:00:12
#    ----------- ---------------------------- 11.6/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 11.7/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 11.8/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 11.9/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.0/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.1/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.2/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.3/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.4/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.5/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------ --------------------------- 12.6/39.0 MB 2.4 MB/s eta 0:00:12
#    ------------- -------------------------- 12.7/39.0 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 12.8/39.0 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 12.9/39.0 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 13.1/39.0 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 13.1/39.0 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 13.3/39.0 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 13.4/39.0 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 13.4/39.0 MB 2.4 MB/s eta 0:00:11
#    ------------- -------------------------- 13.6/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 13.7/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 13.7/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 13.9/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 14.0/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 14.1/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 14.2/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 14.3/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 14.4/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 14.5/39.0 MB 2.4 MB/s eta 0:00:11
#    -------------- ------------------------- 14.6/39.0 MB 2.3 MB/s eta 0:00:11
#    --------------- ------------------------ 14.7/39.0 MB 2.4 MB/s eta 0:00:11
#    --------------- ------------------------ 14.8/39.0 MB 2.4 MB/s eta 0:00:11
#    --------------- ------------------------ 14.9/39.0 MB 2.3 MB/s eta 0:00:11
#    --------------- ------------------------ 15.0/39.0 MB 2.4 MB/s eta 0:00:11
#    --------------- ------------------------ 15.1/39.0 MB 2.3 MB/s eta 0:00:11
#    --------------- ------------------------ 15.2/39.0 MB 2.3 MB/s eta 0:00:11
#    --------------- ------------------------ 15.3/39.0 MB 2.3 MB/s eta 0:00:11
#    --------------- ------------------------ 15.4/39.0 MB 2.3 MB/s eta 0:00:11
#    --------------- ------------------------ 15.5/39.0 MB 2.3 MB/s eta 0:00:11
#    ---------------- ----------------------- 15.6/39.0 MB 2.3 MB/s eta 0:00:11
#    ---------------- ----------------------- 15.7/39.0 MB 2.3 MB/s eta 0:00:11
#    ---------------- ----------------------- 15.9/39.0 MB 2.4 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.0/39.0 MB 2.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.0/39.0 MB 2.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.2/39.0 MB 2.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.3/39.0 MB 2.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.4/39.0 MB 2.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.4/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 16.6/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 16.7/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 16.8/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 16.9/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 17.0/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 17.1/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 17.2/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 17.4/39.0 MB 2.3 MB/s eta 0:00:10
#    ----------------- ---------------------- 17.4/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 17.6/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 17.7/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 17.8/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 17.9/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 18.0/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 18.1/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 18.2/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 18.4/39.0 MB 2.3 MB/s eta 0:00:10
#    ------------------ --------------------- 18.5/39.0 MB 2.3 MB/s eta 0:00:09
#    ------------------- -------------------- 18.6/39.0 MB 2.3 MB/s eta 0:00:09
#    ------------------- -------------------- 18.7/39.0 MB 2.3 MB/s eta 0:00:09
#    ------------------- -------------------- 18.8/39.0 MB 2.3 MB/s eta 0:00:09
#    ------------------- -------------------- 18.9/39.0 MB 2.3 MB/s eta 0:00:09
#    ------------------- -------------------- 19.0/39.0 MB 2.3 MB/s eta 0:00:09
#    ------------------- -------------------- 19.1/39.0 MB 2.4 MB/s eta 0:00:09
#    ------------------- -------------------- 19.2/39.0 MB 2.4 MB/s eta 0:00:09
#    ------------------- -------------------- 19.4/39.0 MB 2.3 MB/s eta 0:00:09
#    ------------------- -------------------- 19.4/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 19.6/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 19.7/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 19.7/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 19.9/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 20.0/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 20.0/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 20.2/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 20.3/39.0 MB 2.3 MB/s eta 0:00:09
#    -------------------- ------------------- 20.4/39.0 MB 2.3 MB/s eta 0:00:09
#    --------------------- ------------------ 20.5/39.0 MB 2.3 MB/s eta 0:00:09
#    --------------------- ------------------ 20.6/39.0 MB 2.3 MB/s eta 0:00:09
#    --------------------- ------------------ 20.7/39.0 MB 2.3 MB/s eta 0:00:08
#    --------------------- ------------------ 20.8/39.0 MB 2.3 MB/s eta 0:00:08
#    --------------------- ------------------ 21.0/39.0 MB 2.3 MB/s eta 0:00:08
#    --------------------- ------------------ 21.1/39.0 MB 2.3 MB/s eta 0:00:08
#    --------------------- ------------------ 21.2/39.0 MB 2.3 MB/s eta 0:00:08
#    --------------------- ------------------ 21.3/39.0 MB 2.3 MB/s eta 0:00:08
#    --------------------- ------------------ 21.4/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 21.5/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 21.6/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 21.7/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 21.8/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 21.9/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 22.0/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 22.1/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 22.2/39.0 MB 2.3 MB/s eta 0:00:08
#    ---------------------- ----------------- 22.4/39.0 MB 2.3 MB/s eta 0:00:08
#    ----------------------- ---------------- 22.4/39.0 MB 2.3 MB/s eta 0:00:08
#    ----------------------- ---------------- 22.6/39.0 MB 2.3 MB/s eta 0:00:08
#    ----------------------- ---------------- 22.7/39.0 MB 2.3 MB/s eta 0:00:08
#    ----------------------- ---------------- 22.8/39.0 MB 2.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 22.9/39.0 MB 2.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 23.0/39.0 MB 2.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 23.1/39.0 MB 2.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 23.2/39.0 MB 2.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 23.4/39.0 MB 2.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 23.4/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 23.5/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 23.5/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 23.5/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 23.8/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 23.8/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 23.9/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 24.0/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 24.1/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 24.2/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------ --------------- 24.3/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------- -------------- 24.4/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------- -------------- 24.5/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------- -------------- 24.6/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------- -------------- 24.8/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------- -------------- 24.9/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------- -------------- 25.0/39.0 MB 2.3 MB/s eta 0:00:07
#    ------------------------- -------------- 25.2/39.0 MB 2.3 MB/s eta 0:00:06
#    ------------------------- -------------- 25.2/39.0 MB 2.3 MB/s eta 0:00:06
#    ------------------------- -------------- 25.3/39.0 MB 2.3 MB/s eta 0:00:06
#    -------------------------- ------------- 25.5/39.0 MB 2.3 MB/s eta 0:00:06
#    -------------------------- ------------- 25.5/39.0 MB 2.3 MB/s eta 0:00:06
#    -------------------------- ------------- 25.7/39.0 MB 2.3 MB/s eta 0:00:06
#    -------------------------- ------------- 25.8/39.0 MB 2.3 MB/s eta 0:00:06
#    -------------------------- ------------- 25.9/39.0 MB 2.3 MB/s eta 0:00:06
#    -------------------------- ------------- 26.0/39.0 MB 2.3 MB/s eta 0:00:06
#    -------------------------- ------------- 26.1/39.0 MB 2.3 MB/s eta 0:00:06
#    -------------------------- ------------- 26.2/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 26.4/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 26.5/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 26.6/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 26.7/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 26.8/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 26.9/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 27.0/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 27.1/39.0 MB 2.3 MB/s eta 0:00:06
#    --------------------------- ------------ 27.3/39.0 MB 2.3 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.3/39.0 MB 2.3 MB/s eta 0:00:05
#    ---------------------------- ----------- 27.4/39.0 MB 2.3 MB/s eta 0:00:05
#    ---------------------------- ----------- 27.6/39.0 MB 2.4 MB/s eta 0:00:05
#    ---------------------------- ----------- 27.7/39.0 MB 2.3 MB/s eta 0:00:05
#    ---------------------------- ----------- 27.8/39.0 MB 2.4 MB/s eta 0:00:05
#    ---------------------------- ----------- 28.0/39.0 MB 2.4 MB/s eta 0:00:05
#    ---------------------------- ----------- 28.0/39.0 MB 2.3 MB/s eta 0:00:05
#    ---------------------------- ----------- 28.1/39.0 MB 2.4 MB/s eta 0:00:05
#    ---------------------------- ----------- 28.3/39.0 MB 2.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 28.3/39.0 MB 2.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 28.5/39.0 MB 2.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 28.6/39.0 MB 2.3 MB/s eta 0:00:05
#    ----------------------------- ---------- 28.7/39.0 MB 2.3 MB/s eta 0:00:05
#    ----------------------------- ---------- 28.8/39.0 MB 2.3 MB/s eta 0:00:05
#    ----------------------------- ---------- 28.9/39.0 MB 2.3 MB/s eta 0:00:05
#    ----------------------------- ---------- 29.0/39.0 MB 2.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 29.1/39.0 MB 2.3 MB/s eta 0:00:05
#    ----------------------------- ---------- 29.2/39.0 MB 2.3 MB/s eta 0:00:05
#    ------------------------------ --------- 29.3/39.0 MB 2.4 MB/s eta 0:00:05
#    ------------------------------ --------- 29.3/39.0 MB 2.3 MB/s eta 0:00:05
#    ------------------------------ --------- 29.3/39.0 MB 2.3 MB/s eta 0:00:05
#    ------------------------------ --------- 29.3/39.0 MB 2.3 MB/s eta 0:00:05
#    ------------------------------ --------- 29.3/39.0 MB 2.3 MB/s eta 0:00:05
#    ------------------------------ --------- 29.3/39.0 MB 2.3 MB/s eta 0:00:05
#    ------------------------------ --------- 29.4/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 29.6/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 29.7/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 29.7/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 29.8/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 29.8/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 30.0/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 30.1/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 30.1/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 30.1/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 30.1/39.0 MB 2.2 MB/s eta 0:00:05
#    ------------------------------ --------- 30.2/39.0 MB 2.1 MB/s eta 0:00:05
#    ------------------------------- -------- 30.6/39.0 MB 2.2 MB/s eta 0:00:04
#    ------------------------------- -------- 30.7/39.0 MB 2.2 MB/s eta 0:00:04
#    ------------------------------- -------- 30.7/39.0 MB 2.2 MB/s eta 0:00:04
#    ------------------------------- -------- 30.8/39.0 MB 2.2 MB/s eta 0:00:04
#    ------------------------------- -------- 31.0/39.0 MB 2.2 MB/s eta 0:00:04
#    ------------------------------- -------- 31.0/39.0 MB 2.2 MB/s eta 0:00:04
#    ------------------------------- -------- 31.1/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 31.2/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 31.3/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 31.4/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 31.5/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 31.5/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 31.7/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 31.8/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 31.8/39.0 MB 2.2 MB/s eta 0:00:04
#    -------------------------------- ------- 32.0/39.0 MB 2.1 MB/s eta 0:00:04
#    -------------------------------- ------- 32.1/39.0 MB 2.1 MB/s eta 0:00:04
#    -------------------------------- ------- 32.1/39.0 MB 2.1 MB/s eta 0:00:04
#    --------------------------------- ------ 32.2/39.0 MB 2.1 MB/s eta 0:00:04
#    --------------------------------- ------ 32.3/39.0 MB 2.1 MB/s eta 0:00:04
#    --------------------------------- ------ 32.4/39.0 MB 2.1 MB/s eta 0:00:04
#    --------------------------------- ------ 32.5/39.0 MB 2.1 MB/s eta 0:00:04
#    --------------------------------- ------ 32.6/39.0 MB 2.1 MB/s eta 0:00:03
#    --------------------------------- ------ 32.7/39.0 MB 2.1 MB/s eta 0:00:03
#    --------------------------------- ------ 32.9/39.0 MB 2.1 MB/s eta 0:00:03
#    --------------------------------- ------ 33.0/39.0 MB 2.1 MB/s eta 0:00:03
#    --------------------------------- ------ 33.0/39.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.2/39.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.3/39.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.4/39.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.5/39.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.6/39.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.7/39.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.8/39.0 MB 2.2 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.9/39.0 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 34.0/39.0 MB 2.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.2/39.0 MB 2.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.3/39.0 MB 2.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.4/39.0 MB 2.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.5/39.0 MB 2.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.6/39.0 MB 2.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.7/39.0 MB 2.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.8/39.0 MB 2.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.9/39.0 MB 2.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.0/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.2/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.3/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.4/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.5/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.6/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.7/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.8/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.9/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.1/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.2/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.3/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.4/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.5/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.6/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.8/39.0 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------- -- 36.8/39.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 37.0/39.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.1/39.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/39.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.3/39.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.4/39.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/39.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/39.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.8/39.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.9/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  38.1/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  38.2/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  38.2/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  38.4/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  38.6/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  38.9/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  39.0/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  39.0/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  39.0/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------  39.0/39.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 2.1 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.9 MB 4.3 MB/s eta 0:00:03
#     --------------------------------------- 0.3/12.9 MB 3.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/12.9 MB 3.1 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/12.9 MB 2.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/12.9 MB 2.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/12.9 MB 2.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/12.9 MB 2.5 MB/s eta 0:00:05
#    -- ------------------------------------- 0.9/12.9 MB 2.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.1/12.9 MB 2.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.1/12.9 MB 2.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.3/12.9 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.4/12.9 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.5/12.9 MB 2.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/12.9 MB 2.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.7/12.9 MB 2.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.9/12.9 MB 2.6 MB/s eta 0:00:05
#    ------ --------------------------------- 2.0/12.9 MB 2.5 MB/s eta 0:00:05
#    ------ --------------------------------- 2.1/12.9 MB 2.5 MB/s eta 0:00:05
#    ------ --------------------------------- 2.2/12.9 MB 2.6 MB/s eta 0:00:05
#    ------- -------------------------------- 2.3/12.9 MB 2.5 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/12.9 MB 2.6 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/12.9 MB 2.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.7/12.9 MB 2.5 MB/s eta 0:00:05
#    -------- ------------------------------- 2.8/12.9 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.9/12.9 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 3.0/12.9 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 3.2/12.9 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.3/12.9 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.9 MB 2.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.5/12.9 MB 2.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.6/12.9 MB 2.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.7/12.9 MB 2.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.8/12.9 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 4.0/12.9 MB 2.6 MB/s eta 0:00:04
#    ------------ --------------------------- 4.1/12.9 MB 2.6 MB/s eta 0:00:04
#    ------------ --------------------------- 4.2/12.9 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 4.3/12.9 MB 2.6 MB/s eta 0:00:04
#    ------------- -------------------------- 4.5/12.9 MB 2.6 MB/s eta 0:00:04
#    -------------- ------------------------- 4.5/12.9 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 4.7/12.9 MB 2.6 MB/s eta 0:00:04
#    -------------- ------------------------- 4.8/12.9 MB 2.5 MB/s eta 0:00:04
#    --------------- ------------------------ 4.9/12.9 MB 2.6 MB/s eta 0:00:04
#    --------------- ------------------------ 5.1/12.9 MB 2.6 MB/s eta 0:00:04
#    --------------- ------------------------ 5.1/12.9 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 5.2/12.9 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 5.2/12.9 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 5.2/12.9 MB 2.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.7/12.9 MB 2.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.8/12.9 MB 2.6 MB/s eta 0:00:03
#    ------------------ --------------------- 5.8/12.9 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 6.0/12.9 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 6.1/12.9 MB 2.6 MB/s eta 0:00:03
#    ------------------ --------------------- 6.1/12.9 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 6.2/12.9 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 6.3/12.9 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 6.4/12.9 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 6.5/12.9 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 6.6/12.9 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 6.7/12.9 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.9 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 6.9/12.9 MB 2.5 MB/s eta 0:00:03
#    --------------------- ------------------ 7.0/12.9 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.1/12.9 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.2/12.9 MB 2.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.3/12.9 MB 2.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.4/12.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.5/12.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.6/12.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.7/12.9 MB 2.4 MB/s eta 0:00:03
#    ------------------------ --------------- 7.8/12.9 MB 2.4 MB/s eta 0:00:03
#    ------------------------ --------------- 7.9/12.9 MB 2.4 MB/s eta 0:00:03
#    ------------------------ --------------- 8.0/12.9 MB 2.4 MB/s eta 0:00:03
#    ------------------------- -------------- 8.1/12.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 8.2/12.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 8.3/12.9 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.9 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 8.5/12.9 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 8.6/12.9 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 8.8/12.9 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 8.8/12.9 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 8.9/12.9 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.1/12.9 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.1/12.9 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.3/12.9 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.4/12.9 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.4/12.9 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.6/12.9 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.7/12.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 9.7/12.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 9.9/12.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 10.0/12.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 10.1/12.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 10.1/12.9 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 10.3/12.9 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.4/12.9 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.5/12.9 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.6/12.9 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.9 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 10.8/12.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.1/12.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.1/12.9 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.9 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.4/12.9 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.5/12.9 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.7/12.9 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.9 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.9/12.9 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 12.0/12.9 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 12.2/12.9 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.4/12.9 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.5/12.9 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  12.9/12.9 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 2.3 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\skfim\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\skfim\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\~umpy'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\skfim\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
class ImageExtractorWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = env.observation_space['screen']

    def observation(self, observation: Dict) -> np.ndarray:
        return observation['screen']


def make_env():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    env = ImageExtractorWrapper(env)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    env = FrameStack(env, num_stack=3)
    env = RecordEpisodeStatistics(env)
    env = TransformReward(env, f=lambda reward: reward / 100.)

    return env


def wrapped_env_info():
    config_file_path = create_vizdoom_config()
    env = make_env()
    env.reset()
    terminated = False
    while not terminated:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

    fig, axes = plt.subplots(1, 3, figsize=(12, 3))
    for ax, frame in zip(axes, obs):
        ax.imshow(frame, cmap='gray')

    print('Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape:', obs.shape)
    plt.show()
    print('info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах\n', info)

DEMO_WRAPPED_ENV = True
if DEMO_WRAPPED_ENV:
    wrapped_env_info()
# Out:
# Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape: (3, 84, 84)
# info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах
#  {'episode': {'r': array([-108.23819], dtype=float32), 'l': array([418], dtype=int32), 't': array([4.5625], dtype=float32)}}

# %% [markdown]
# ### Misc

# %%
def set_seed_everywhere(seed: int, using_cuda: bool = False) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if using_cuda:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# # 1 REINFORCE

# %% [markdown]
# ### Policy
# Основные компоненты ReinforcePolicy:
# - `features_extractor` - свёрточный энкодер, кодирующий изображения в латентный вектор
# - `action_net` - полносвязный слой, который выдаёт логиты действий для предсказания вероятностей

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            observation_space: gym.Space,
            features_dim: int = 512,
    ) -> None:
        super().__init__()
        self.features_dim = features_dim
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


class ReinforcePolicy(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5},):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        self.features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        features = self.features_extractor(obs)

        return features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))

        return {'features': features, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()

        return {'features': features, 'log_prob': log_prob, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %% [markdown]
# ### Buffer
# В буфере хранятся траектории, собранные агентом. Также в буфере производится вычисление частичных отдач по траекториям.

# %%
class BufferSamples(NamedTuple):
    observations: torch.Tensor
    actions: torch.Tensor
    returns: torch.Tensor


class Buffer:
    def __init__(
            self,
            gamma: float = 0.99,
            device: Union[torch.device, str] = "cpu",
    ):
        self.device = torch.device(device)
        self.gamma = gamma
        self.observations = None
        self.actions = None
        self.rewards = None
        self.returns = None

    def reset(self) -> None:
        self.observations = []
        self.actions = []
        self.rewards = []
        self.returns = None

    def size(self) -> int:
        return len(self.actions)

    def add(
            self,
            obs: np.ndarray,
            action: int,
            reward: float,
    ) -> None:
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)

    def to_torch(self, array: np.ndarray) -> torch.Tensor:
        return torch.tensor(array, device=self.device)

    def _get_samples(
            self,
            batch_inds: np.ndarray,
    ) -> BufferSamples:
        observations = self.to_torch(self.observations[batch_inds])
        actions = self.to_torch(self.actions[batch_inds])
        returns = self.to_torch(self.returns[batch_inds])

        return BufferSamples(observations=observations, actions=actions, returns=returns)

    def get(self) -> BufferSamples:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        self.observations = np.asarray(self.observations)
        self.actions = np.asarray(self.actions)
        self.returns = np.asarray(self.returns, dtype=np.float32)

        return self._get_samples(indices)

    def compute_returns(self) -> None:
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for step in reversed(range(len(self.rewards))):
            reward_to_go = self.rewards[step] + self.gamma * reward_to_go
            returns[step] = reward_to_go

        self.returns = returns

# %% [markdown]
# ### Обучение стратегии по методу REINFORCE
# - Метод `learn`: реализует основной цикл RL-обучения: чередование фазы сбора данных (траекторий) агентом в среде - `collect_rollouts` и фазы обучения агента - `train`.
# - Метод `collect_rollouts`: агент выполняет действия в среде согласно текущей стратегии, собирая триплеты **<observation, action, reward>** в буфер
# - Метод `train`: обучение на собранных данных. Функция потерь состоит из двух слагаемых: градиент стратегии и энтропийная регуляризация. Энтропийная регуляризация делает стратегию более стохастичной, т.е. более устойчивой к шуму, помогает исследовать среду, предотвращает сходимость к субоптимальному решению (особенно в средах с дискретными действиями)

# %% [markdown]
# ![learn](data:image/png;base64,...)

# %% [markdown]
# ![reinforce](data:image/png;base64,...)

# %%
class Reinforce:
    def __init__(
            self,
            env: gym.Env,
            learning_rate: float = 2.5e-4,
            gamma: float = 0.99,
            ent_coef: float = 0.001,
            max_grad_norm: float = 0.5,
            stats_window_size: int = 10,
            policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
            policy_kwargs: Optional[Dict[str, Any]] = None,
            buffer_class: Type[Buffer] = Buffer,
            buffer_kwargs: Optional[Dict[str, Any]] = None,
            seed: Optional[int] = None,
            device: Union[torch.device, str] = "cuda",
    ):
        self.device = device if isinstance(device, torch.device) else torch.device(device)
        print(f"Using {self.device} device")

        self.policy_kwargs = {} if policy_kwargs is None else policy_kwargs

        self.num_timesteps = 0
        self._num_timesteps_at_start = 0
        self._episode_num = 0
        self.seed = seed
        self.start_time = 0.0
        self.learning_rate = learning_rate
        self._last_obs = None
        self._stats_window_size = stats_window_size
        self.ep_info_buffer = deque(maxlen=self._stats_window_size)
        self._n_updates = 0

        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.env = env

        self.n_steps = None
        self.gamma = gamma
        self.ent_coef = ent_coef
        self.max_grad_norm = max_grad_norm
        self.log_dict = {}

        self.set_random_seed(self.seed)
        self.buffer_class = buffer_class
        self.buffer_kwargs = {} if buffer_kwargs is None else buffer_kwargs
        self.buffer = self.buffer_class(
            device=self.device,
            gamma=self.gamma,
            **self.buffer_kwargs,
        )
        self.policy_class = policy_class
        self.policy = self.policy_class(
            self.observation_space, self.action_space, self.learning_rate, **self.policy_kwargs
        )
        self.policy = self.policy.to(self.device)

    def _update_info_buffer(self, info: Dict[str, Any]) -> None:
        # Collect statistics
        assert self.ep_info_buffer is not None

        ep_info = info.get("episode")
        if ep_info is not None:
            self.ep_info_buffer.append(ep_info)

    def set_random_seed(self, seed: Optional[int] = None) -> None:
        if seed is None:
            return
        set_seed_everywhere(seed, using_cuda=self.device.type == torch.device("cuda").type)
        self.action_space.seed(seed)
        self.observation_space.seed(seed)

    def collect_rollouts(
            self,
            env,
            buffer: Buffer,
    ):
        self.policy.set_training_mode(False)
        self._last_obs, _ = self.env.reset()
        self._last_obs = np.array(self._last_obs)
        assert self._last_obs is not None, "No previous observation was provided"

        buffer.reset()
        terminated = False
        while not terminated:
            with torch.no_grad():
                obs_tensor = torch.as_tensor(self._last_obs, device=self.device)
                action = self.policy(obs_tensor.unsqueeze(0))['action']
            action = action.item()
            new_obs, reward, terminated, truncated, info = env.step(action)
            assert not truncated, 'Episode truncation must be off as we want to use Monte Carlo estimation'

            self.num_timesteps += 1
            self._episode_num += int(terminated)
            buffer.add(
                self._last_obs,
                action,
                reward,
            )

            self._last_obs = np.array(new_obs)
            self._update_info_buffer(info)

        buffer.compute_returns()

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        returns = rollout_data.returns

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates)
        ])

    def get_current_mean_return(self) -> float:
        if len(self.ep_info_buffer) == 0:
            return -math.inf

        return np.mean(np.concatenate([ep_info["r"] for ep_info in self.ep_info_buffer])).item()

    def _dump_logs(self, iteration: int) -> None:
        assert self.ep_info_buffer is not None

        time_elapsed = max((time.time_ns() - self.start_time) / 1e9, sys.float_info.epsilon)
        fps = int((self.num_timesteps - self._num_timesteps_at_start) / time_elapsed)
        self.log_dict["time/iterations"] = iteration
        if len(self.ep_info_buffer) > 0 and len(self.ep_info_buffer[0]) > 0:
            self.log_dict["rollout/ep_rew_mean"] = self.get_current_mean_return()
            self.log_dict["rollout/ep_len_mean"] = np.mean(
                np.concatenate([ep_info["l"] for ep_info in self.ep_info_buffer])).item()

        self.log_dict["time/fps"] = fps
        self.log_dict["time/time_elapsed"] = int(time_elapsed)
        self.log_dict["global_step"] = self.num_timesteps
        self.log_dict["num_episodes"] = self._episode_num
        print(json.dumps(self.log_dict, sort_keys=True, indent=4))

        if WANDB_IS_AVAILABLE and wandb.run is not None:
            wandb.log(self.log_dict)

    def learn(
            self,
            max_timesteps: int,
            expected_return: float,
            log_interval: int = 1000,
            save_checkpoint_path: str = None,
            save_checkpoint_interval: int = 5000,
    ) -> None:
        assert self.env is not None

        self.start_time = time.time_ns()
        self.num_timesteps = 0
        self._episode_num = 0
        self._num_timesteps_at_start = 0
        log_interval = log_interval or math.inf
        if save_checkpoint_path is None or save_checkpoint_interval is None or not COLAB:
            save_checkpoint_interval = math.inf

        next_log_step = self.num_timesteps + log_interval
        next_save_step = self.num_timesteps + save_checkpoint_interval

        if self._last_obs is None:
            self._last_obs, _ = self.env.reset(seed=self.seed)

        iteration = 0
        while True:
            if self.get_current_mean_return() >= expected_return:
                print('Решено!')
                break

            if self.num_timesteps >= max_timesteps:
                print(f'Задача не решена за {max_timesteps} шагов')
                break

            self.collect_rollouts(self.env, self.buffer, )
            iteration += 1

            if self.num_timesteps >= next_log_step:
                assert self.ep_info_buffer is not None
                self._dump_logs(iteration)
                next_log_step += log_interval

            if self.num_timesteps >= next_save_step:
                next_save_step += save_checkpoint_interval
                checkpoint = {'policy': self.policy.state_dict(), 'optimizer': self.policy.optimizer.state_dict(),
                              'num_timesteps': self.num_timesteps, 'episode_num': self._episode_num,
                              'ep_info_buffer': self.ep_info_buffer}
                os.makedirs(save_checkpoint_path, exist_ok=True)
                torch.save(checkpoint, os.path.join(save_checkpoint_path, 'checkpoint.pt'))

            self.train()

# %%
def run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs):
    env = make_env()
    model = algorithm_class(env, **algorithm_kwargs)
    if use_wandb:
        config = {}
        config.update(algorithm_kwargs)
        config.update(learn_kwargs)
        config.update(wandb_kwargs.get('config', {}))
        wandb_kwargs['config'] = config
        if wandb.run is not None:
            wandb.finish()

        wandb.init(**wandb_kwargs)

    model.learn(**learn_kwargs)
    if use_wandb:
        wandb.finish()

# %%
# !wandb login "e97ffa4c776cbfb2c0fc0c8b5c97e875139c1d42" --relogin
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\skfim\_netrc

# %%
run_algorithm(
    algorithm_class=Reinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                      )
)
# Out:
# C:\Users\skfim\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# You can sync this run to the cloud by running:<br><code>wandb sync c:\Users\skfim\RL\RL25\practices\prac5\wandb\offline-run-20251101_180715-te4ui7sw<code>
# Find logs at: <code>.\wandb\offline-run-20251101_180715-te4ui7sw\logs</code>
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1303,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 434.3333333333333,
#     "rollout/ep_rew_mean": -58.70725631713867,
#     "time/fps": 63,
#     "time/iterations": 3,
#     "time/time_elapsed": 20,
#     "train/entropy": 2.078981637954712,
#     "train/entropy_loss": -0.002078981837257743,
#     "train/grad_norm": 0.017130590975284576,
#     "train/loss": -0.18334105610847473,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.1812620759010315
# }
# {
#     "global_step": 2129,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 425.8,
#     "rollout/ep_rew_mean": -52.0356330871582,
#     "time/fps": 64,
#     "time/iterations": 5,
#     "time/time_elapsed": 32,
#     "train/entropy": 2.078382730484009,
#     "train/entropy_loss": -0.0020783827640116215,
#     "train/grad_norm": 0.020274391397833824,
#     "train/loss": -0.1716112494468689,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": -0.1695328652858734
# }
# {
#     "global_step": 3262,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 543.6666666666666,
#     "rollout/ep_rew_mean": -62.00615310668945,
#     "time/fps": 65,
#     "time/iterations": 6,
#     "time/time_elapsed": 49,
#     "train/entropy": 2.0792808532714844,
#     "train/entropy_loss": -0.002079281024634838,
#     "train/grad_norm": 0.010885899886488914,
#     "train/loss": -0.21753457188606262,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.2154552936553955
# }
# {
#     "global_step": 4322,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 480.22222222222223,
#     "rollout/ep_rew_mean": -74.3956298828125,
#     "time/fps": 66,
#     "time/iterations": 9,
#     "time/time_elapsed": 65,
#     "train/entropy": 2.079213857650757,
#     "train/entropy_loss": -0.002079213969409466,
#     "train/grad_norm": 0.029307447373867035,
#     "train/loss": -0.7571735978126526,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.7550944089889526
# }
# {
#     "global_step": 5005,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 459.3,
#     "rollout/ep_rew_mean": -72.21192932128906,
#     "time/fps": 66,
#     "time/iterations": 11,
#     "time/time_elapsed": 75,
#     "train/entropy": 2.07887864112854,
#     "train/entropy_loss": -0.0020788786932826042,
#     "train/grad_norm": 0.02094390243291855,
#     "train/loss": -0.3919503688812256,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": -0.3898714780807495
# }
# {
#     "global_step": 7565,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 626.2,
#     "rollout/ep_rew_mean": -50.60826110839844,
#     "time/fps": 66,
#     "time/iterations": 13,
#     "time/time_elapsed": 113,
#     "train/entropy": 2.07900071144104,
#     "train/entropy_loss": -0.002079000696539879,
#     "train/grad_norm": 0.00680191908031702,
#     "train/loss": -0.3285099267959595,
#     "train/n_updates": 12,
#     "train/policy_gradient_loss": -0.32643091678619385
# }
# {
#     "global_step": 7868,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 613.0,
#     "rollout/ep_rew_mean": -55.54765701293945,
#     "time/fps": 66,
#     "time/iterations": 14,
#     "time/time_elapsed": 118,
#     "train/entropy": 2.0788755416870117,
#     "train/entropy_loss": -0.0020788756664842367,
#     "train/grad_norm": 0.011352777481079102,
#     "train/loss": 0.20267216861248016,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 0.20475104451179504
# }
# {
#     "global_step": 8313,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 618.4,
#     "rollout/ep_rew_mean": -54.416038513183594,
#     "time/fps": 66,
#     "time/iterations": 15,
#     "time/time_elapsed": 124,
#     "train/entropy": 2.0784952640533447,
#     "train/entropy_loss": -0.00207849545404315,
#     "train/grad_norm": 0.042938295751810074,
#     "train/loss": -0.9031103253364563,
#     "train/n_updates": 14,
#     "train/policy_gradient_loss": -0.9010318517684937
# }
# {
#     "global_step": 9095,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 517.9,
#     "rollout/ep_rew_mean": -0.7188354730606079,
#     "time/fps": 66,
#     "time/iterations": 18,
#     "time/time_elapsed": 136,
#     "train/entropy": 1.7043739557266235,
#     "train/entropy_loss": -0.001704373979009688,
#     "train/grad_norm": 0.35469239950180054,
#     "train/loss": 1.4061368703842163,
#     "train/n_updates": 17,
#     "train/policy_gradient_loss": 1.4078412055969238
# }
# {
#     "global_step": 10212,
#     "num_episodes": 21,
#     "rollout/ep_len_mean": 520.7,
#     "rollout/ep_rew_mean": 74.1252212524414,
#     "time/fps": 66,
#     "time/iterations": 21,
#     "time/time_elapsed": 153,
#     "train/entropy": 1.9323668479919434,
#     "train/entropy_loss": -0.0019323669839650393,
#     "train/grad_norm": 0.10693959146738052,
#     "train/loss": 0.7641157507896423,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": 0.7660481333732605
# }
# {
#     "global_step": 11132,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 281.9,
#     "rollout/ep_rew_mean": 178.43260192871094,
#     "time/fps": 66,
#     "time/iterations": 25,
#     "time/time_elapsed": 166,
#     "train/entropy": 2.01116681098938,
#     "train/entropy_loss": -0.002011166885495186,
#     "train/grad_norm": 0.14075566828250885,
#     "train/loss": 0.9151068329811096,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": 0.9171180129051208
# }
# {
#     "global_step": 12107,
#     "num_episodes": 29,
#     "rollout/ep_len_mean": 255.6,
#     "rollout/ep_rew_mean": 260.1509094238281,
#     "time/fps": 66,
#     "time/iterations": 29,
#     "time/time_elapsed": 181,
#     "train/entropy": 1.8202171325683594,
#     "train/entropy_loss": -0.0018202172359451652,
#     "train/grad_norm": 0.29261353611946106,
#     "train/loss": 1.61307954788208,
#     "train/n_updates": 28,
#     "train/policy_gradient_loss": 1.614899754524231
# }
# {
#     "global_step": 13024,
#     "num_episodes": 34,
#     "rollout/ep_len_mean": 220.8,
#     "rollout/ep_rew_mean": 549.2513427734375,
#     "time/fps": 66,
#     "time/iterations": 34,
#     "time/time_elapsed": 195,
#     "train/entropy": 0.49071890115737915,
#     "train/entropy_loss": -0.0004907189286313951,
#     "train/grad_norm": 1.5320624113082886,
#     "train/loss": 1.25674569606781,
#     "train/n_updates": 33,
#     "train/policy_gradient_loss": 1.257236361503601
# }
# {
#     "global_step": 14015,
#     "num_episodes": 40,
#     "rollout/ep_len_mean": 169.3,
#     "rollout/ep_rew_mean": 1771.7193603515625,
#     "time/fps": 66,
#     "time/iterations": 40,
#     "time/time_elapsed": 210,
#     "train/entropy": 0.00018029999046120793,
#     "train/entropy_loss": -1.803000060363047e-07,
#     "train/grad_norm": 0.008388319052755833,
#     "train/loss": 0.00012827629689127207,
#     "train/n_updates": 39,
#     "train/policy_gradient_loss": 0.00012845659512095153
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▂▃▃▄▅▅▅▆▆▇▇█</td></tr><tr><td>num_episodes</td><td>▁▁▂▂▃▃▃▃▄▄▅▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▅▅▇▆▅███▆▆▃▂▂▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▃█</td></tr><tr><td>time/fps</td><td>▁▃▆███████████</td></tr><tr><td>time/iterations</td><td>▁▁▂▂▃▃▃▃▄▄▅▆▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▁▂▃▃▄▅▅▅▆▆▇▇█</td></tr><tr><td>train/entropy</td><td>████████▇██▇▃▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▂▁▁▂▆█</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▃▁▂▂█▁</td></tr><tr><td>train/loss</td><td>▃▃▃▁▂▃▄▁▇▆▆█▇▄</td></tr><tr><td>train/n_updates</td><td>▁▁▂▂▃▃▃▃▄▄▅▆▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▃▃▃▁▂▃▄▁▇▆▆█▇▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>14015</td></tr><tr><td>num_episodes</td><td>40</td></tr><tr><td>rollout/ep_len_mean</td><td>169.3</td></tr><tr><td>rollout/ep_rew_mean</td><td>1771.71936</td></tr><tr><td>time/fps</td><td>66</td></tr><tr><td>time/iterations</td><td>40</td></tr><tr><td>time/time_elapsed</td><td>210</td></tr><tr><td>train/entropy</td><td>0.00018</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00839</td></tr><tr><td>train/loss</td><td>0.00013</td></tr><tr><td>train/n_updates</td><td>39</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00013</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync c:\Users\skfim\RL\RL25\practices\prac5\wandb\offline-run-20251101_180931-m9p8lddl<code>
# Find logs at: <code>.\wandb\offline-run-20251101_180931-m9p8lddl\logs</code>

# %% [markdown]
# # 2 REINFORCE с базовым уровнем
# Градиент стратагии зависит от величины отдачи. Однако отдача может быть очень шумной оценкой $Q ^ {\pi} (s, a)$, особенно в средах с отложенными или редкими вознаграждениями. Этот шум приводит к высокой дисперсии в оценках градиента, что влечёт за собой сильные изменения стратегии. При этом обучение становится нестабильным, а сходимость медленной. Одним из способов снижения дисперсии является использование базового уровня $b(s)$. Базовый уровень $b(s)$ не зависит от действий, поэтому вычитание из оценки $Q ^ {\pi} (s, a)$ не приводит к смещению оценки градиента.
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [(G_t - b(s)) \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# ## 2.1 REINFORCE с необучаемым базовым уровнем (средняя отдача)
# В некоторых случаях в качестве базового уровня достаточно использовать среднюю отдачу за предыдущие эпизоды. Даже такая простая эвристика может помочь стабилизировать процесс обучения на ранних этапах.

# %% [markdown]
# (3 балла)

# %%
class AverageReturnBuffer(Buffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cuda"):
        super().__init__(gamma, device)
        self.all_episode_returns = []
    
    def get_average_return(self):
        if len(self.all_episode_returns) == 0:
            return 0.0
        return np.mean(self.all_episode_returns)

    def compute_returns(self) -> None:
        super().compute_returns()
        if len(self.returns) > 0:
            episode_return = self.returns[0]
            self.all_episode_returns.append(episode_return)

# %% [markdown]
# (1 балл)

# %%
class AverageReturnBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[AverageReturnBuffer] = AverageReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda"):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']

        baseline = self.buffer.get_average_return()
        returns = rollout_data.returns - baseline

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %%
run_algorithm(
    algorithm_class=AverageReturnBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_simple-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,)
)
# Out:
# C:\Users\skfim\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# You can sync this run to the cloud by running:<br><code>wandb sync c:\Users\skfim\RL\RL25\practices\prac5\wandb\offline-run-20251101_181728-t4mak7b0<code>
# Find logs at: <code>.\wandb\offline-run-20251101_181728-t4mak7b0\logs</code>
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1449,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 483.0,
#     "rollout/ep_rew_mean": -51.17240524291992,
#     "time/fps": 65,
#     "time/iterations": 3,
#     "time/time_elapsed": 22,
#     "train/baseline": -0.0616217084486066,
#     "train/entropy": 2.0790016651153564,
#     "train/entropy_loss": -0.002079001860693097,
#     "train/grad_norm": 0.017316825687885284,
#     "train/loss": -0.05507490411400795,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.05299590155482292
# }
# {
#     "global_step": 2117,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 423.4,
#     "rollout/ep_rew_mean": -54.295310974121094,
#     "time/fps": 65,
#     "time/iterations": 5,
#     "time/time_elapsed": 32,
#     "train/baseline": -0.008692851945982825,
#     "train/entropy": 2.078871965408325,
#     "train/entropy_loss": -0.002078872174024582,
#     "train/grad_norm": 0.026903590187430382,
#     "train/loss": -0.410812109708786,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": -0.4087332487106323
# }
# {
#     "global_step": 3250,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 541.6666666666666,
#     "rollout/ep_rew_mean": -61.17738723754883,
#     "time/fps": 65,
#     "time/iterations": 6,
#     "time/time_elapsed": 49,
#     "train/baseline": 0.0017819388970322578,
#     "train/entropy": 2.079164505004883,
#     "train/entropy_loss": -0.002079164609313011,
#     "train/grad_norm": 0.012567668221890926,
#     "train/loss": -0.33453354239463806,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.3324543833732605
# }
# {
#     "global_step": 4276,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 475.1111111111111,
#     "rollout/ep_rew_mean": -61.34524154663086,
#     "time/fps": 65,
#     "time/iterations": 9,
#     "time/time_elapsed": 64,
#     "train/baseline": 0.004062140773213903,
#     "train/entropy": 2.0789191722869873,
#     "train/entropy_loss": -0.0020789192058146,
#     "train/grad_norm": 0.013359880074858665,
#     "train/loss": -0.2629111111164093,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.26083219051361084
# }
# {
#     "global_step": 5056,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 464.4,
#     "rollout/ep_rew_mean": -58.81043243408203,
#     "time/fps": 65,
#     "time/iterations": 11,
#     "time/time_elapsed": 76,
#     "train/baseline": -0.012656078743058224,
#     "train/entropy": 2.078883409500122,
#     "train/entropy_loss": -0.002078883582726121,
#     "train/grad_norm": 0.017412690445780754,
#     "train/loss": -0.2649919092655182,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": -0.2629130184650421
# }
# {
#     "global_step": 6256,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 480.7,
#     "rollout/ep_rew_mean": -62.04042434692383,
#     "time/fps": 65,
#     "time/iterations": 13,
#     "time/time_elapsed": 95,
#     "train/baseline": -0.006856681356315828,
#     "train/entropy": 2.078800678253174,
#     "train/entropy_loss": -0.00207880069501698,
#     "train/grad_norm": 0.017483128234744072,
#     "train/loss": -0.410430908203125,
#     "train/n_updates": 12,
#     "train/policy_gradient_loss": -0.4083521068096161
# }
# {
#     "global_step": 7986,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 473.6,
#     "rollout/ep_rew_mean": -71.7994155883789,
#     "time/fps": 66,
#     "time/iterations": 16,
#     "time/time_elapsed": 120,
#     "train/baseline": -0.010027790613464522,
#     "train/entropy": 2.0788168907165527,
#     "train/entropy_loss": -0.002078816993162036,
#     "train/grad_norm": 0.019628234207630157,
#     "train/loss": -0.5990864038467407,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": -0.5970075726509094
# }
# {
#     "global_step": 8260,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 474.8,
#     "rollout/ep_rew_mean": -73.61206817626953,
#     "time/fps": 65,
#     "time/iterations": 17,
#     "time/time_elapsed": 125,
#     "train/baseline": -0.006987247228319416,
#     "train/entropy": 2.0781874656677246,
#     "train/entropy_loss": -0.0020781876519322395,
#     "train/grad_norm": 0.01851029135286808,
#     "train/loss": -0.17407679557800293,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": -0.17199860513210297
# }
# {
#     "global_step": 9274,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 462.2,
#     "rollout/ep_rew_mean": -76.00230407714844,
#     "time/fps": 65,
#     "time/iterations": 20,
#     "time/time_elapsed": 140,
#     "train/baseline": -0.008204520216562223,
#     "train/entropy": 2.078313112258911,
#     "train/entropy_loss": -0.002078313147649169,
#     "train/grad_norm": 0.0269361212849617,
#     "train/loss": -0.5538128614425659,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": -0.5517345666885376
# }
# {
#     "global_step": 11374,
#     "num_episodes": 21,
#     "rollout/ep_len_mean": 631.8,
#     "rollout/ep_rew_mean": -42.96278381347656,
#     "time/fps": 65,
#     "time/iterations": 21,
#     "time/time_elapsed": 172,
#     "train/baseline": -0.008561631716525955,
#     "train/entropy": 2.0768697261810303,
#     "train/entropy_loss": -0.0020768698304891586,
#     "train/grad_norm": 0.022575728595256805,
#     "train/loss": -0.37100180983543396,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": -0.36892494559288025
# }
# {
#     "global_step": 12095,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 654.3,
#     "rollout/ep_rew_mean": -39.41851806640625,
#     "time/fps": 65,
#     "time/iterations": 22,
#     "time/time_elapsed": 183,
#     "train/baseline": -0.007824278755190891,
#     "train/entropy": 2.078476667404175,
#     "train/entropy_loss": -0.0020784768275916576,
#     "train/grad_norm": 0.014321536757051945,
#     "train/loss": 0.24973732233047485,
#     "train/n_updates": 21,
#     "train/policy_gradient_loss": 0.2518157958984375
# }
# {
#     "global_step": 12773,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 651.7,
#     "rollout/ep_rew_mean": -18.695106506347656,
#     "time/fps": 65,
#     "time/iterations": 23,
#     "time/time_elapsed": 193,
#     "train/baseline": -0.007841500839866804,
#     "train/entropy": 2.0778725147247314,
#     "train/entropy_loss": -0.002077872632071376,
#     "train/grad_norm": 0.013621198013424873,
#     "train/loss": -0.1382644921541214,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": -0.1361866146326065
# }
# {
#     "global_step": 13206,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 670.9,
#     "rollout/ep_rew_mean": 14.239133834838867,
#     "time/fps": 65,
#     "time/iterations": 24,
#     "time/time_elapsed": 200,
#     "train/baseline": 0.005444202546865578,
#     "train/entropy": 2.0769848823547363,
#     "train/entropy_loss": -0.0020769850816577673,
#     "train/grad_norm": 0.03372123837471008,
#     "train/loss": 0.5819830894470215,
#     "train/n_updates": 23,
#     "train/policy_gradient_loss": 0.5840600728988647
# }
# {
#     "global_step": 14036,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 577.6,
#     "rollout/ep_rew_mean": 309.8942565917969,
#     "time/fps": 66,
#     "time/iterations": 27,
#     "time/time_elapsed": 212,
#     "train/baseline": 0.28624594895260674,
#     "train/entropy": 0.12059398740530014,
#     "train/entropy_loss": -0.00012059399159625173,
#     "train/grad_norm": 0.38450103998184204,
#     "train/loss": 0.39505016803741455,
#     "train/n_updates": 26,
#     "train/policy_gradient_loss": 0.39517074823379517
# }
# {
#     "global_step": 15013,
#     "num_episodes": 33,
#     "rollout/ep_len_mean": 224.0,
#     "rollout/ep_rew_mean": 1523.7208251953125,
#     "time/fps": 66,
#     "time/iterations": 33,
#     "time/time_elapsed": 227,
#     "train/baseline": 1.4594182516168626,
#     "train/entropy": 0.00011197034473298118,
#     "train/entropy_loss": -1.1197035121313093e-07,
#     "train/grad_norm": 0.004387015011161566,
#     "train/loss": 6.299308006418869e-05,
#     "train/n_updates": 32,
#     "train/policy_gradient_loss": 6.310504977591336e-05
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▂▂▃▃▄▅▅▆▆▇▇▇█</td></tr><tr><td>num_episodes</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇█</td></tr><tr><td>rollout/ep_len_mean</td><td>▅▄▆▅▅▅▅▅▅▇███▇▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▃█</td></tr><tr><td>time/fps</td><td>▁▁▁▁▁▁█▁▁▁▁▁▁██</td></tr><tr><td>time/iterations</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇█</td></tr><tr><td>time/time_elapsed</td><td>▁▁▂▂▃▃▄▅▅▆▆▇▇▇█</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▃█</td></tr><tr><td>train/entropy</td><td>█████████████▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁██</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▂█▁</td></tr><tr><td>train/loss</td><td>▄▂▃▃▃▂▁▄▁▂▆▄█▇▅</td></tr><tr><td>train/n_updates</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇█</td></tr><tr><td>train/policy_gradient_loss</td><td>▄▂▃▃▃▂▁▄▁▂▆▄█▇▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>15013</td></tr><tr><td>num_episodes</td><td>33</td></tr><tr><td>rollout/ep_len_mean</td><td>224</td></tr><tr><td>rollout/ep_rew_mean</td><td>1523.72083</td></tr><tr><td>time/fps</td><td>66</td></tr><tr><td>time/iterations</td><td>33</td></tr><tr><td>time/time_elapsed</td><td>227</td></tr><tr><td>train/baseline</td><td>1.45942</td></tr><tr><td>train/entropy</td><td>0.00011</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00439</td></tr><tr><td>train/loss</td><td>6e-05</td></tr><tr><td>train/n_updates</td><td>32</td></tr><tr><td>train/policy_gradient_loss</td><td>6e-05</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync c:\Users\skfim\RL\RL25\practices\prac5\wandb\offline-run-20251101_182148-apmsajiq<code>
# Find logs at: <code>.\wandb\offline-run-20251101_182148-apmsajiq\logs</code>

# %% [markdown]
# ## 2.2 REINFORCE с обучаемым базовым уровнем
# Чаще всего в качестве базового уровня применяется оценка функции полезности состояний $b(s) = v(s) = \mathbb{E}[G_t| s_t = s]$, получаемая с помощью нейросетевой аппроксимации. При этом величину $G_t - b(s_t)$ можно рассматривать как оценку функции преимущества (advantage) действия $a_t$ в состоянии $s_t$: $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$.
#
# #### Shared-encoder
# Модели стратегии и функции полезности могут обучаться в разных режимах — стратегия только on-policy (шаг обучения на текущей собранной подтраектории), а полезность on-policy или off-policy (шаг обучения на текущей подтраектории или на батче из replay buffer). Это с одной стороны привносит гибкость в обучение, с другой — усложняет его.
#
# Если обе модели обучаются on-policy, то имеет смысл объединить их сетки в одну и делать общий шаг обратного распространения ошибки. Однако, если они обучаются в разных режимах (и с разной частотой обновления), то велика вероятность, что их шаги обучения могут начать конфликтовать в случае общего тела — для такого варианта намного предпочтительнее разделить их на разные подсети (либо аккуратно настраивать гиперпарметры, чтобы стабилизировать обучение). В целом, рекомендуется использовать общий энкодер наблюдений, а далее как можно скорее разделять головы.

# %% [markdown]
# (2 балла)

# %%
class ValuePolicy(ReinforcePolicy):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5}):
        super().__init__(observation_space, action_space, lr, optimizer_class, optimizer_kwargs)
        self.value_net = nn.Linear(self.features_extractor.features_dim, 1)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        policy_output = super().evaluate_actions(obs, actions_taken)
        features = policy_output['features']
        
        values = self.value_net(features).squeeze(-1) 
        
        policy_output['values'] = values
        
        return policy_output

# %% [markdown]
# (1 балл)

# %%
class ValueBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ValuePolicy] = ValuePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[Buffer] = Buffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", vf_coef: float = 0.5,):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class,
                         policy_kwargs, buffer_class, buffer_kwargs, seed, device)
        self.vf_coef = vf_coef

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        values = policy_output['values']  # Исправлено: должно быть 'values' (с 's')
        advantages = rollout_data.returns - values.detach()
        baseline = values.mean().item()

        # Policy gradient loss
        policy_loss = -(advantages * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        # Value loss с коэффициентов self.vf_coef
        # MSE между предсказанными values и фактическими returns
        value_loss = self.vf_coef * F.mse_loss(values, rollout_data.returns)

        loss = policy_loss + entropy_loss + value_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline), ("train/value_loss", value_loss.item())
        ])

# %%
run_algorithm(
    algorithm_class=ValueBaselineReinforce,
    algorithm_kwargs=dict(seed=0, ),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_value-baseline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000)
)
# Out:
# C:\Users\skfim\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1375,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 458.3333333333333,
#     "rollout/ep_rew_mean": -45.55570602416992,
#     "time/fps": 65,
#     "time/iterations": 3,
#     "time/time_elapsed": 21,
#     "train/baseline": -0.2724339962005615,
#     "train/entropy": 2.078947067260742,
#     "train/entropy_loss": -0.0020789471454918385,
#     "train/grad_norm": 0.5415685176849365,
#     "train/loss": 0.5374072194099426,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": 0.4557025730609894,
#     "train/value_loss": 0.08378361165523529
# }
# {
#     "global_step": 2184,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 436.8,
#     "rollout/ep_rew_mean": -53.1938591003418,
#     "time/fps": 66,
#     "time/iterations": 5,
#     "time/time_elapsed": 33,
#     "train/baseline": -0.023643260821700096,
#     "train/entropy": 2.079281806945801,
#     "train/entropy_loss": -0.0020792819559574127,
#     "train/grad_norm": 0.15074743330478668,
#     "train/loss": -0.19942250847816467,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": -0.25557559728622437,
#     "train/value_loss": 0.058232370764017105
# }
# {
#     "global_step": 3181,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 530.1666666666666,
#     "rollout/ep_rew_mean": -56.25369644165039,
#     "time/fps": 66,
#     "time/iterations": 6,
#     "time/time_elapsed": 47,
#     "train/baseline": -0.08295772969722748,
#     "train/entropy": 2.079178810119629,
#     "train/entropy_loss": -0.002079178811982274,
#     "train/grad_norm": 0.11520829051733017,
#     "train/loss": -0.12471520900726318,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.174434095621109,
#     "train/value_loss": 0.051798056811094284
# }
# {
#     "global_step": 4438,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 493.1111111111111,
#     "rollout/ep_rew_mean": -67.2107925415039,
#     "time/fps": 66,
#     "time/iterations": 9,
#     "time/time_elapsed": 66,
#     "train/baseline": -0.07171228528022766,
#     "train/entropy": 2.0791738033294678,
#     "train/entropy_loss": -0.0020791739225387573,
#     "train/grad_norm": 0.3298931419849396,
#     "train/loss": -0.4513179659843445,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.5528837442398071,
#     "train/value_loss": 0.1036449521780014
# }
# {
#     "global_step": 5299,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 488.7,
#     "rollout/ep_rew_mean": -68.47660064697266,
#     "time/fps": 66,
#     "time/iterations": 11,
#     "time/time_elapsed": 79,
#     "train/baseline": -0.16617071628570557,
#     "train/entropy": 2.0790247917175293,
#     "train/entropy_loss": -0.002079024910926819,
#     "train/grad_norm": 0.1825283020734787,
#     "train/loss": -0.14211946725845337,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": -0.21932347118854523,
#     "train/value_loss": 0.07928302139043808
# }
# {
#     "global_step": 6135,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 476.0,
#     "rollout/ep_rew_mean": -83.18194580078125,
#     "time/fps": 66,
#     "time/iterations": 13,
#     "time/time_elapsed": 92,
#     "train/baseline": -0.18321315944194794,
#     "train/entropy": 2.078636646270752,
#     "train/entropy_loss": -0.002078636782243848,
#     "train/grad_norm": 0.01766766421496868,
#     "train/loss": 0.007437234744429588,
#     "train/n_updates": 12,
#     "train/policy_gradient_loss": -0.013606281019747257,
#     "train/value_loss": 0.02312215231359005
# }
# {
#     "global_step": 7737,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 455.6,
#     "rollout/ep_rew_mean": -83.134033203125,
#     "time/fps": 66,
#     "time/iterations": 16,
#     "time/time_elapsed": 117,
#     "train/baseline": -0.2708924114704132,
#     "train/entropy": 2.077471971511841,
#     "train/entropy_loss": -0.002077472163364291,
#     "train/grad_norm": 0.09921276569366455,
#     "train/loss": -0.03783078119158745,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": -0.08399789035320282,
#     "train/value_loss": 0.04824458435177803
# }
# {
#     "global_step": 8080,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 445.1,
#     "rollout/ep_rew_mean": -87.70231628417969,
#     "time/fps": 65,
#     "time/iterations": 17,
#     "time/time_elapsed": 122,
#     "train/baseline": -0.34237995743751526,
#     "train/entropy": 2.0762243270874023,
#     "train/entropy_loss": -0.00207622442394495,
#     "train/grad_norm": 0.8863925337791443,
#     "train/loss": 0.7747648358345032,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 0.6826145648956299,
#     "train/value_loss": 0.09422645717859268
# }
# {
#     "global_step": 9346,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 451.7,
#     "rollout/ep_rew_mean": -77.87519836425781,
#     "time/fps": 65,
#     "time/iterations": 20,
#     "time/time_elapsed": 142,
#     "train/baseline": -0.21132336556911469,
#     "train/entropy": 2.0777831077575684,
#     "train/entropy_loss": -0.0020777832251042128,
#     "train/grad_norm": 0.12317071110010147,
#     "train/loss": 0.21114623546600342,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": 0.13792024552822113,
#     "train/value_loss": 0.07530377805233002
# }
# {
#     "global_step": 10255,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 412.0,
#     "rollout/ep_rew_mean": -73.98292541503906,
#     "time/fps": 65,
#     "time/iterations": 23,
#     "time/time_elapsed": 156,
#     "train/baseline": -0.20809291303157806,
#     "train/entropy": 2.0775063037872314,
#     "train/entropy_loss": -0.0020775063894689083,
#     "train/grad_norm": 0.036584049463272095,
#     "train/loss": 0.09541144967079163,
#     "train/n_updates": 22,
#     "train/policy_gradient_loss": 0.030295653268694878,
#     "train/value_loss": 0.06719329953193665
# }
# {
#     "global_step": 11371,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 454.1,
#     "rollout/ep_rew_mean": -61.72303009033203,
#     "time/fps": 65,
#     "time/iterations": 25,
#     "time/time_elapsed": 173,
#     "train/baseline": -0.27873364090919495,
#     "train/entropy": 2.0757884979248047,
#     "train/entropy_loss": -0.00207578856498003,
#     "train/grad_norm": 0.5786644220352173,
#     "train/loss": 0.6131553053855896,
#     "train/n_updates": 24,
#     "train/policy_gradient_loss": 0.5203324556350708,
#     "train/value_loss": 0.09489864856004715
# }
# {
#     "global_step": 12642,
#     "num_episodes": 28,
#     "rollout/ep_len_mean": 419.9,
#     "rollout/ep_rew_mean": -43.64916229248047,
#     "time/fps": 65,
#     "time/iterations": 28,
#     "time/time_elapsed": 192,
#     "train/baseline": -0.18747489154338837,
#     "train/entropy": 2.076849937438965,
#     "train/entropy_loss": -0.002076850039884448,
#     "train/grad_norm": 0.2162426859140396,
#     "train/loss": -0.16816085577011108,
#     "train/n_updates": 27,
#     "train/policy_gradient_loss": -0.2388976365327835,
#     "train/value_loss": 0.07281363010406494
# }
# {
#     "global_step": 13060,
#     "num_episodes": 30,
#     "rollout/ep_len_mean": 371.4,
#     "rollout/ep_rew_mean": -36.31684112548828,
#     "time/fps": 65,
#     "time/iterations": 30,
#     "time/time_elapsed": 199,
#     "train/baseline": -0.14039374887943268,
#     "train/entropy": 2.0772948265075684,
#     "train/entropy_loss": -0.0020772949792444706,
#     "train/grad_norm": 0.20125027000904083,
#     "train/loss": -0.15920385718345642,
#     "train/n_updates": 29,
#     "train/policy_gradient_loss": -0.26002737879753113,
#     "train/value_loss": 0.10290081053972244
# }
# {
#     "global_step": 14002,
#     "num_episodes": 33,
#     "rollout/ep_len_mean": 374.7,
#     "rollout/ep_rew_mean": -24.311403274536133,
#     "time/fps": 65,
#     "time/iterations": 33,
#     "time/time_elapsed": 213,
#     "train/baseline": -0.18219693005084991,
#     "train/entropy": 2.075108289718628,
#     "train/entropy_loss": -0.002075108466669917,
#     "train/grad_norm": 0.08817947655916214,
#     "train/loss": 0.20241153240203857,
#     "train/n_updates": 32,
#     "train/policy_gradient_loss": 0.11342982202768326,
#     "train/value_loss": 0.09105682373046875
# }
# {
#     "global_step": 15021,
#     "num_episodes": 36,
#     "rollout/ep_len_mean": 329.2,
#     "rollout/ep_rew_mean": -15.031590461730957,
#     "time/fps": 65,
#     "time/iterations": 36,
#     "time/time_elapsed": 229,
#     "train/baseline": -0.16148750483989716,
#     "train/entropy": 2.075479030609131,
#     "train/entropy_loss": -0.002075479133054614,
#     "train/grad_norm": 0.07524511218070984,
#     "train/loss": -0.02465703710913658,
#     "train/n_updates": 35,
#     "train/policy_gradient_loss": -0.06723559647798538,
#     "train/value_loss": 0.044654037803411484
# }
# {
#     "global_step": 16080,
#     "num_episodes": 39,
#     "rollout/ep_len_mean": 323.5,
#     "rollout/ep_rew_mean": -40.0696907043457,
#     "time/fps": 65,
#     "time/iterations": 39,
#     "time/time_elapsed": 245,
#     "train/baseline": -0.17512574791908264,
#     "train/entropy": 2.0736048221588135,
#     "train/entropy_loss": -0.0020736048463732004,
#     "train/grad_norm": 0.2090292125940323,
#     "train/loss": -0.19071076810359955,
#     "train/n_updates": 38,
#     "train/policy_gradient_loss": -0.23846295475959778,
#     "train/value_loss": 0.04982578381896019
# }
# {
#     "global_step": 17035,
#     "num_episodes": 41,
#     "rollout/ep_len_mean": 368.3,
#     "rollout/ep_rew_mean": -40.440574645996094,
#     "time/fps": 65,
#     "time/iterations": 41,
#     "time/time_elapsed": 260,
#     "train/baseline": -0.19110138714313507,
#     "train/entropy": 2.0715997219085693,
#     "train/entropy_loss": -0.0020715997088700533,
#     "train/grad_norm": 0.2449847161769867,
#     "train/loss": 0.3208239674568176,
#     "train/n_updates": 40,
#     "train/policy_gradient_loss": 0.28070327639579773,
#     "train/value_loss": 0.04219227656722069
# }
# {
#     "global_step": 18116,
#     "num_episodes": 44,
#     "rollout/ep_len_mean": 383.5,
#     "rollout/ep_rew_mean": -21.068342208862305,
#     "time/fps": 65,
#     "time/iterations": 44,
#     "time/time_elapsed": 276,
#     "train/baseline": -0.15952812135219574,
#     "train/entropy": 2.0725314617156982,
#     "train/entropy_loss": -0.002072531497105956,
#     "train/grad_norm": 0.35216304659843445,
#     "train/loss": -0.2771099805831909,
#     "train/n_updates": 43,
#     "train/policy_gradient_loss": -0.38621971011161804,
#     "train/value_loss": 0.11118226498365402
# }
# {
#     "global_step": 19164,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 378.2,
#     "rollout/ep_rew_mean": -11.828323364257812,
#     "time/fps": 65,
#     "time/iterations": 47,
#     "time/time_elapsed": 292,
#     "train/baseline": -0.13570016622543335,
#     "train/entropy": 2.0717954635620117,
#     "train/entropy_loss": -0.002071795519441366,
#     "train/grad_norm": 0.10407309234142303,
#     "train/loss": -0.08346375823020935,
#     "train/n_updates": 46,
#     "train/policy_gradient_loss": -0.1293235570192337,
#     "train/value_loss": 0.047931596636772156
# }
# {
#     "global_step": 20167,
#     "num_episodes": 50,
#     "rollout/ep_len_mean": 347.0,
#     "rollout/ep_rew_mean": -25.51693344116211,
#     "time/fps": 65,
#     "time/iterations": 50,
#     "time/time_elapsed": 307,
#     "train/baseline": -0.17492668330669403,
#     "train/entropy": 2.06805157661438,
#     "train/entropy_loss": -0.002068051602691412,
#     "train/grad_norm": 0.15684933960437775,
#     "train/loss": -0.1135801374912262,
#     "train/n_updates": 49,
#     "train/policy_gradient_loss": -0.15751977264881134,
#     "train/value_loss": 0.04600768908858299
# }
# {
#     "global_step": 21033,
#     "num_episodes": 53,
#     "rollout/ep_len_mean": 346.8,
#     "rollout/ep_rew_mean": -17.098920822143555,
#     "time/fps": 65,
#     "time/iterations": 53,
#     "time/time_elapsed": 320,
#     "train/baseline": -0.18042980134487152,
#     "train/entropy": 2.0639822483062744,
#     "train/entropy_loss": -0.0020639824215322733,
#     "train/grad_norm": 0.13961216807365417,
#     "train/loss": -0.0654929056763649,
#     "train/n_updates": 52,
#     "train/policy_gradient_loss": -0.12697330117225647,
#     "train/value_loss": 0.0635443851351738
# }
# {
#     "global_step": 22077,
#     "num_episodes": 56,
#     "rollout/ep_len_mean": 341.0,
#     "rollout/ep_rew_mean": -3.6730148792266846,
#     "time/fps": 65,
#     "time/iterations": 56,
#     "time/time_elapsed": 335,
#     "train/baseline": -0.14596611261367798,
#     "train/entropy": 2.063140392303467,
#     "train/entropy_loss": -0.002063140505924821,
#     "train/grad_norm": 0.8343160152435303,
#     "train/loss": 1.2536877393722534,
#     "train/n_updates": 55,
#     "train/policy_gradient_loss": 1.0177638530731201,
#     "train/value_loss": 0.23798707127571106
# }
# {
#     "global_step": 23536,
#     "num_episodes": 59,
#     "rollout/ep_len_mean": 365.8,
#     "rollout/ep_rew_mean": 26.412822723388672,
#     "time/fps": 65,
#     "time/iterations": 59,
#     "time/time_elapsed": 357,
#     "train/baseline": -0.09142973273992538,
#     "train/entropy": 2.0682785511016846,
#     "train/entropy_loss": -0.0020682786125689745,
#     "train/grad_norm": 0.13521957397460938,
#     "train/loss": 0.24804770946502686,
#     "train/n_updates": 58,
#     "train/policy_gradient_loss": 0.19524720311164856,
#     "train/value_loss": 0.05486879497766495
# }
# {
#     "global_step": 24122,
#     "num_episodes": 61,
#     "rollout/ep_len_mean": 359.2,
#     "rollout/ep_rew_mean": 31.54473876953125,
#     "time/fps": 65,
#     "time/iterations": 61,
#     "time/time_elapsed": 366,
#     "train/baseline": -0.04277318716049194,
#     "train/entropy": 2.0715560913085938,
#     "train/entropy_loss": -0.00207155616953969,
#     "train/grad_norm": 0.08544252067804337,
#     "train/loss": -0.0692853033542633,
#     "train/n_updates": 60,
#     "train/policy_gradient_loss": -0.12205877900123596,
#     "train/value_loss": 0.05484503507614136
# }
# {
#     "global_step": 25379,
#     "num_episodes": 64,
#     "rollout/ep_len_mean": 409.3,
#     "rollout/ep_rew_mean": 39.991519927978516,
#     "time/fps": 65,
#     "time/iterations": 64,
#     "time/time_elapsed": 386,
#     "train/baseline": -0.08178824186325073,
#     "train/entropy": 2.066467761993408,
#     "train/entropy_loss": -0.0020664678886532784,
#     "train/grad_norm": 0.21100394427776337,
#     "train/loss": -0.23811209201812744,
#     "train/n_updates": 63,
#     "train/policy_gradient_loss": -0.30212879180908203,
#     "train/value_loss": 0.06608317047357559
# }
# {
#     "global_step": 26006,
#     "num_episodes": 67,
#     "rollout/ep_len_mean": 354.0,
#     "rollout/ep_rew_mean": 2.505654811859131,
#     "time/fps": 65,
#     "time/iterations": 67,
#     "time/time_elapsed": 395,
#     "train/baseline": -0.09624975174665451,
#     "train/entropy": 2.0650136470794678,
#     "train/entropy_loss": -0.00206501386128366,
#     "train/grad_norm": 0.2600747346878052,
#     "train/loss": -0.300734281539917,
#     "train/n_updates": 66,
#     "train/policy_gradient_loss": -0.34791436791419983,
#     "train/value_loss": 0.04924507811665535
# }
# {
#     "global_step": 27201,
#     "num_episodes": 72,
#     "rollout/ep_len_mean": 272.0,
#     "rollout/ep_rew_mean": 0.09868927299976349,
#     "time/fps": 65,
#     "time/iterations": 72,
#     "time/time_elapsed": 414,
#     "train/baseline": -0.18082067370414734,
#     "train/entropy": 2.0410046577453613,
#     "train/entropy_loss": -0.00204100483097136,
#     "train/grad_norm": 0.3355458378791809,
#     "train/loss": 0.36181196570396423,
#     "train/n_updates": 71,
#     "train/policy_gradient_loss": 0.31768110394477844,
#     "train/value_loss": 0.04617186635732651
# }
# {
#     "global_step": 28405,
#     "num_episodes": 76,
#     "rollout/ep_len_mean": 258.3,
#     "rollout/ep_rew_mean": 0.5428192019462585,
#     "time/fps": 65,
#     "time/iterations": 76,
#     "time/time_elapsed": 432,
#     "train/baseline": -0.09455044567584991,
#     "train/entropy": 2.0554635524749756,
#     "train/entropy_loss": -0.0020554636139422655,
#     "train/grad_norm": 0.07595539838075638,
#     "train/loss": 0.12689661979675293,
#     "train/n_updates": 75,
#     "train/policy_gradient_loss": 0.06803817301988602,
#     "train/value_loss": 0.060913920402526855
# }
# {
#     "global_step": 29178,
#     "num_episodes": 79,
#     "rollout/ep_len_mean": 265.2,
#     "rollout/ep_rew_mean": 49.52191162109375,
#     "time/fps": 65,
#     "time/iterations": 79,
#     "time/time_elapsed": 444,
#     "train/baseline": -0.08367035537958145,
#     "train/entropy": 2.05045747756958,
#     "train/entropy_loss": -0.0020504575222730637,
#     "train/grad_norm": 0.7533657550811768,
#     "train/loss": 1.284597396850586,
#     "train/n_updates": 78,
#     "train/policy_gradient_loss": 0.9572027325630188,
#     "train/value_loss": 0.32944512367248535
# }
# {
#     "global_step": 30221,
#     "num_episodes": 83,
#     "rollout/ep_len_mean": 283.0,
#     "rollout/ep_rew_mean": 67.98936462402344,
#     "time/fps": 65,
#     "time/iterations": 83,
#     "time/time_elapsed": 460,
#     "train/baseline": -0.036479756236076355,
#     "train/entropy": 2.0435779094696045,
#     "train/entropy_loss": -0.0020435780752450228,
#     "train/grad_norm": 0.47803086042404175,
#     "train/loss": 0.7405416369438171,
#     "train/n_updates": 82,
#     "train/policy_gradient_loss": 0.5869473814964294,
#     "train/value_loss": 0.15563786029815674
# }
# {
#     "global_step": 31132,
#     "num_episodes": 86,
#     "rollout/ep_len_mean": 272.7,
#     "rollout/ep_rew_mean": 85.78585815429688,
#     "time/fps": 65,
#     "time/iterations": 86,
#     "time/time_elapsed": 474,
#     "train/baseline": 0.007145584560930729,
#     "train/entropy": 2.033316135406494,
#     "train/entropy_loss": -0.002033316297456622,
#     "train/grad_norm": 0.16976314783096313,
#     "train/loss": 0.25102293491363525,
#     "train/n_updates": 85,
#     "train/policy_gradient_loss": 0.183217853307724,
#     "train/value_loss": 0.06983841210603714
# }
# {
#     "global_step": 32144,
#     "num_episodes": 90,
#     "rollout/ep_len_mean": 274.3,
#     "rollout/ep_rew_mean": 112.32713317871094,
#     "time/fps": 65,
#     "time/iterations": 90,
#     "time/time_elapsed": 490,
#     "train/baseline": 0.04900549724698067,
#     "train/entropy": 2.009506940841675,
#     "train/entropy_loss": -0.0020095070358365774,
#     "train/grad_norm": 0.7639473080635071,
#     "train/loss": 0.8591090440750122,
#     "train/n_updates": 89,
#     "train/policy_gradient_loss": 0.7120496034622192,
#     "train/value_loss": 0.14906898140907288
# }
# {
#     "global_step": 33266,
#     "num_episodes": 96,
#     "rollout/ep_len_mean": 213.4,
#     "rollout/ep_rew_mean": 374.47955322265625,
#     "time/fps": 65,
#     "time/iterations": 96,
#     "time/time_elapsed": 507,
#     "train/baseline": 1.9095531702041626,
#     "train/entropy": 0.366583913564682,
#     "train/entropy_loss": -0.0003665839321911335,
#     "train/grad_norm": 3.565284252166748,
#     "train/loss": 1.1778117418289185,
#     "train/n_updates": 95,
#     "train/policy_gradient_loss": 0.18458327651023865,
#     "train/value_loss": 0.9935950040817261
# }
# {
#     "global_step": 34081,
#     "num_episodes": 101,
#     "rollout/ep_len_mean": 169.0,
#     "rollout/ep_rew_mean": 1130.2935791015625,
#     "time/fps": 65,
#     "time/iterations": 101,
#     "time/time_elapsed": 520,
#     "train/baseline": 5.276909828186035,
#     "train/entropy": 0.011600871570408344,
#     "train/entropy_loss": -1.1600872312556021e-05,
#     "train/grad_norm": 153.74671936035156,
#     "train/loss": 8.34404182434082,
#     "train/n_updates": 100,
#     "train/policy_gradient_loss": 0.004930608905851841,
#     "train/value_loss": 8.339122772216797
# }
# {
#     "global_step": 35065,
#     "num_episodes": 107,
#     "rollout/ep_len_mean": 160.8,
#     "rollout/ep_rew_mean": 2125.456787109375,
#     "time/fps": 65,
#     "time/iterations": 107,
#     "time/time_elapsed": 535,
#     "train/baseline": 9.860902786254883,
#     "train/entropy": 0.0001465344976168126,
#     "train/entropy_loss": -1.4653450364221499e-07,
#     "train/grad_norm": 41.48305130004883,
#     "train/loss": 0.5679244995117188,
#     "train/n_updates": 106,
#     "train/policy_gradient_loss": -6.879099146317458e-06,
#     "train/value_loss": 0.5679315328598022
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>num_episodes</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>rollout/ep_len_mean</td><td>▇▆█▇▇▇▇▆▇▆▇▆▅▅▄▄▅▅▅▅▅▄▅▅▆▅▃▃▃▃▃▃▂▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▅█</td></tr><tr><td>time/fps</td><td>▁██████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/iterations</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>time/time_elapsed</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▅█</td></tr><tr><td>train/entropy</td><td>████████████████████████████████▂▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▇██</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▃</td></tr><tr><td>train/loss</td><td>▂▁▁▁▁▁▁▂▂▁▂▁▁▂▁▁▂▁▁▁▁▂▂▁▁▁▂▁▂▂▂▂▂█▂</td></tr><tr><td>train/n_updates</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>train/policy_gradient_loss</td><td>▅▂▃▁▂▃▃▇▄▄▆▂▂▄▃▂▅▂▃▃▃█▄▃▂▂▅▄█▆▄▇▄▃▃</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>35065</td></tr><tr><td>num_episodes</td><td>107</td></tr><tr><td>rollout/ep_len_mean</td><td>160.8</td></tr><tr><td>rollout/ep_rew_mean</td><td>2125.45679</td></tr><tr><td>time/fps</td><td>65</td></tr><tr><td>time/iterations</td><td>107</td></tr><tr><td>time/time_elapsed</td><td>535</td></tr><tr><td>train/baseline</td><td>9.8609</td></tr><tr><td>train/entropy</td><td>0.00015</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>41.48305</td></tr><tr><td>train/loss</td><td>0.56792</td></tr><tr><td>train/n_updates</td><td>106</td></tr><tr><td>train/policy_gradient_loss</td><td>-1e-05</td></tr><tr><td>train/value_loss</td><td>0.56793</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync c:\Users\skfim\RL\RL25\practices\prac5\wandb\offline-run-20251101_183414-qvu1jp16<code>
# Find logs at: <code>.\wandb\offline-run-20251101_183414-qvu1jp16\logs</code>

# %% [markdown]
# # 3 REINFORCE с разбиением на мини-батчи
# В предыдущих реализациях по данным одной собранной траетории стратегия обновлялась только один раз. Попробуем разбить траекторию на мини-батчи и обучаться на одной траектории в течение нескольких эпох. С одной стороны это должно привести к ускорению обучения, поскольку модели будут обновляться чаще. С другой стороны такая схема обучения отходит от on-policy режима.

# %%
class BatchedReturnBuffer(AverageReturnBuffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.generator_ready = None

    def reset(self) -> None:
        super().reset()
        self.generator_ready = False

    def get(self, batch_size: Optional[Union[int, float]] = None) -> Generator[BufferSamples, None, None]:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        if not self.generator_ready:
            self.observations = np.asarray(self.observations)
            self.actions = np.asarray(self.actions)
            self.returns = np.asarray(self.returns, dtype=np.float32)
            self.generator_ready = True

        if batch_size is None or math.isinf(batch_size):
            batch_size = buffer_size

        start_idx = 0
        while start_idx < buffer_size:
            yield self._get_samples(indices[start_idx: start_idx + batch_size])
            start_idx += batch_size

# %% [markdown]
# (3 балла)

# %%
class BatchedAverageReturnReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[BatchedReturnBuffer] = BatchedReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", batch_size: Union[int, float] = 64, n_epochs: int = 1):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)
        self.batch_size = batch_size
        self.n_epochs = n_epochs

    def train(self) -> None:
        # В train выполняется self.n_epochs проходов по буферу.
        # Данные из буфера сэмплируются батчами размера self.batch_size: self.buffer.get(self.batch_size).
        # Тело функции аналогично методу train в AverageReturnBaselineReinforce,
        # единственное отличие - несколько эпох обучения и обучение на батчах.
        self.policy.set_training_mode(True)
        
        # Переменные для хранения метрик последней итерации
        final_policy_loss = None
        final_entropy_loss = None
        final_entropy = None
        final_baseline = None
        final_grad_norm = None

        # Проходим по всем эпохам
        for epoch_idx in range(self.n_epochs):
            # Инициализируем накопитель loss для текущей эпохи
            accumulated_loss = torch.tensor(0.0, device=self.device)
            
            # Получаем генератор батчей и обрабатываем каждый батч
            for batch_data in self.buffer.get(self.batch_size):
                # Подготовка действий и вычисление policy output
                action_indices = batch_data.actions.long()
                policy_result = self.policy.evaluate_actions(batch_data.observations, action_indices)
                
                log_probs = policy_result['log_prob']
                entropy_values = policy_result['entropy']
                
                # Получаем исходные returns из батча
                batch_returns = batch_data.returns
                
                # Вычисляем baseline (средняя отдача)
                current_baseline = self.buffer.get_average_return()
                
                # Вычитаем baseline из returns для получения advantages
                advantages = batch_returns - current_baseline
                
                # Вычисляем policy gradient loss
                pg_loss = -(advantages * log_probs).mean()
                
                # Вычисляем entropy loss
                mean_entropy = torch.mean(entropy_values)
                ent_loss = -self.ent_coef * mean_entropy
                
                # Накопление loss с нормализацией по размеру батча
                accumulated_loss += (pg_loss + ent_loss) / self.batch_size
                
                # Сохраняем метрики последнего батча для логирования
                final_policy_loss = pg_loss
                final_entropy_loss = ent_loss
                final_entropy = mean_entropy
                final_baseline = current_baseline
            
            # Оптимизация выполняется один раз после всех батчей в эпохе
            self.policy.optimizer.zero_grad()
            accumulated_loss.backward()
            final_grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.policy.optimizer.step()

        # Обновление счетчика обновлений (один раз после всех эпох)
        self._n_updates += 1

        # Формирование словаря для логирования
        self.log_dict = dict([
            ("train/entropy_loss", final_entropy_loss.item() if final_entropy_loss is not None else 0.0),
            ("train/entropy", final_entropy.item() if final_entropy is not None else 0.0),
            ("train/policy_gradient_loss", final_policy_loss.item() if final_policy_loss is not None else 0.0),
            ("train/loss", accumulated_loss.item() if accumulated_loss is not None else 0.0),
            ("train/grad_norm", final_grad_norm.item() if final_grad_norm is not None else 0.0),
            ("train/n_updates", self._n_updates),
            ("train/baseline", final_baseline if final_baseline is not None else 0.0)
        ])

# %% [markdown]
# ### Одна эпоха обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=1),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-1'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,)
)
# Out:
# C:\Users\skfim\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# You can sync this run to the cloud by running:<br><code>wandb sync c:\Users\skfim\RL\RL25\practices\prac5\wandb\offline-run-20251101_185855-g0lgzycp<code>
# Find logs at: <code>.\wandb\offline-run-20251101_185855-g0lgzycp\logs</code>
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1320,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 440.0,
#     "rollout/ep_rew_mean": -115.4803466796875,
#     "time/fps": 65,
#     "time/iterations": 3,
#     "time/time_elapsed": 20,
#     "train/baseline": -0.10685007546578948,
#     "train/entropy": 0.000431365300755715,
#     "train/entropy_loss": -4.313653185761268e-07,
#     "train/grad_norm": 7.883621390192275e-05,
#     "train/loss": 8.259004147248561e-08,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": 5.139553707067535e-07
# }
# {
#     "global_step": 2228,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 445.6,
#     "rollout/ep_rew_mean": -115.6860580444336,
#     "time/fps": 66,
#     "time/iterations": 5,
#     "time/time_elapsed": 33,
#     "train/baseline": -0.1008893335898993,
#     "train/entropy": 0.00042413723713252693,
#     "train/entropy_loss": -4.2413725864776097e-07,
#     "train/grad_norm": 6.982510990383162e-05,
#     "train/loss": 5.004507279693371e-07,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 9.24587965300816e-07
# }
# {
#     "global_step": 3136,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 448.0,
#     "rollout/ep_rew_mean": -115.77422332763672,
#     "time/fps": 66,
#     "time/iterations": 7,
#     "time/time_elapsed": 47,
#     "train/baseline": -0.09890241963126924,
#     "train/entropy": 0.0004273356025805697,
#     "train/entropy_loss": -4.2733562111152423e-07,
#     "train/grad_norm": 5.900314556583908e-05,
#     "train/loss": 6.586324161617085e-07,
#     "train/n_updates": 47,
#     "train/policy_gradient_loss": 1.0859680443786601e-06
# }
# {
#     "global_step": 4453,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 445.3,
#     "rollout/ep_rew_mean": -115.83872985839844,
#     "time/fps": 66,
#     "time/iterations": 10,
#     "time/time_elapsed": 66,
#     "train/baseline": -0.10043584618699403,
#     "train/entropy": 0.0004064933782501612,
#     "train/entropy_loss": -4.0649339538845197e-07,
#     "train/grad_norm": 5.8456238946291705e-05,
#     "train/loss": 8.929642092425638e-08,
#     "train/n_updates": 70,
#     "train/policy_gradient_loss": 4.957898056545673e-07
# }
# {
#     "global_step": 5231,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 436.5,
#     "rollout/ep_rew_mean": -115.99298095703125,
#     "time/fps": 67,
#     "time/iterations": 12,
#     "time/time_elapsed": 77,
#     "train/baseline": -0.10233269382413614,
#     "train/entropy": 0.0004316298485112687,
#     "train/entropy_loss": -4.316298714002187e-07,
#     "train/grad_norm": 9.554032779609163e-05,
#     "train/loss": -1.3288683362588927e-06,
#     "train/n_updates": 84,
#     "train/policy_gradient_loss": -8.972384624901982e-07
# }
# {
#     "global_step": 6012,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 423.8,
#     "rollout/ep_rew_mean": -115.9920654296875,
#     "time/fps": 67,
#     "time/iterations": 14,
#     "time/time_elapsed": 89,
#     "train/baseline": -0.10387951441056106,
#     "train/entropy": 0.0004415589210111648,
#     "train/entropy_loss": -4.4155893874631147e-07,
#     "train/grad_norm": 9.050691793769754e-05,
#     "train/loss": -2.258043897048386e-07,
#     "train/n_updates": 97,
#     "train/policy_gradient_loss": 2.1575455851537603e-07
# }
# {
#     "global_step": 7062,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 392.6,
#     "rollout/ep_rew_mean": -115.99166107177734,
#     "time/fps": 67,
#     "time/iterations": 17,
#     "time/time_elapsed": 105,
#     "train/baseline": -0.10699294757488656,
#     "train/entropy": 0.00042211713662254624,
#     "train/entropy_loss": -4.221171536755719e-07,
#     "train/grad_norm": 5.2845404752588365e-05,
#     "train/loss": 2.163383605591207e-07,
#     "train/n_updates": 117,
#     "train/policy_gradient_loss": 6.384555035765516e-07
# }
# {
#     "global_step": 8415,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 396.2,
#     "rollout/ep_rew_mean": -115.99290466308594,
#     "time/fps": 67,
#     "time/iterations": 20,
#     "time/time_elapsed": 124,
#     "train/baseline": -0.10778229310275918,
#     "train/entropy": 0.0004546270065475255,
#     "train/entropy_loss": -4.546270354745098e-07,
#     "train/grad_norm": 0.00010312003663178378,
#     "train/loss": -1.1771051333653304e-06,
#     "train/n_updates": 138,
#     "train/policy_gradient_loss": -7.22478104206756e-07
# }
# {
#     "global_step": 9323,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 409.2,
#     "rollout/ep_rew_mean": -115.99295806884766,
#     "time/fps": 67,
#     "time/iterations": 22,
#     "time/time_elapsed": 137,
#     "train/baseline": -0.10655813106573538,
#     "train/entropy": 0.00042396899152663536,
#     "train/entropy_loss": -4.23969012786074e-07,
#     "train/grad_norm": 8.786462899479375e-05,
#     "train/loss": 7.926048262163476e-07,
#     "train/n_updates": 154,
#     "train/policy_gradient_loss": 1.2165738070279986e-06
# }
# {
#     "global_step": 10189,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 417.7,
#     "rollout/ep_rew_mean": -115.99214935302734,
#     "time/fps": 67,
#     "time/iterations": 24,
#     "time/time_elapsed": 150,
#     "train/baseline": -0.10516600519318386,
#     "train/entropy": 0.0004002092672245843,
#     "train/entropy_loss": -4.0020928590170766e-07,
#     "train/grad_norm": 8.596802282616929e-05,
#     "train/loss": 1.0329467110230845e-07,
#     "train/n_updates": 169,
#     "train/policy_gradient_loss": 5.035039529437719e-07
# }
# {
#     "global_step": 11142,
#     "num_episodes": 26,
#     "rollout/ep_len_mean": 442.0,
#     "rollout/ep_rew_mean": -115.99072265625,
#     "time/fps": 67,
#     "time/iterations": 26,
#     "time/time_elapsed": 165,
#     "train/baseline": -0.10414272064539977,
#     "train/entropy": 0.0004254270934325177,
#     "train/entropy_loss": -4.2542711042869996e-07,
#     "train/grad_norm": 0.00012688282595263445,
#     "train/loss": -1.7117601558425122e-06,
#     "train/n_updates": 185,
#     "train/policy_gradient_loss": -1.2863330169921028e-06
# }
# {
#     "global_step": 12217,
#     "num_episodes": 29,
#     "rollout/ep_len_mean": 425.6,
#     "rollout/ep_rew_mean": -115.99174499511719,
#     "time/fps": 67,
#     "time/iterations": 29,
#     "time/time_elapsed": 181,
#     "train/baseline": -0.10531999216796908,
#     "train/entropy": 0.00040864423499442637,
#     "train/entropy_loss": -4.086442544348756e-07,
#     "train/grad_norm": 6.88232944412448e-05,
#     "train/loss": -1.3475202820245613e-07,
#     "train/n_updates": 205,
#     "train/policy_gradient_loss": 2.738922262324195e-07
# }
# {
#     "global_step": 13183,
#     "num_episodes": 31,
#     "rollout/ep_len_mean": 431.4,
#     "rollout/ep_rew_mean": -115.99151611328125,
#     "time/fps": 67,
#     "time/iterations": 31,
#     "time/time_elapsed": 195,
#     "train/baseline": -0.10504464793785938,
#     "train/entropy": 0.0004888622352154925,
#     "train/entropy_loss": -4.888622555654365e-07,
#     "train/grad_norm": 9.894230925056036e-05,
#     "train/loss": -1.2164362246380733e-06,
#     "train/n_updates": 219,
#     "train/policy_gradient_loss": -7.275739619672095e-07
# }
# {
#     "global_step": 14384,
#     "num_episodes": 34,
#     "rollout/ep_len_mean": 419.5,
#     "rollout/ep_rew_mean": -115.99284362792969,
#     "time/fps": 67,
#     "time/iterations": 34,
#     "time/time_elapsed": 213,
#     "train/baseline": -0.1058917934173728,
#     "train/entropy": 0.0004940981394611299,
#     "train/entropy_loss": -4.940981568779534e-07,
#     "train/grad_norm": 0.0001324465702055022,
#     "train/loss": -1.916596374940127e-06,
#     "train/n_updates": 239,
#     "train/policy_gradient_loss": -1.422498195324806e-06
# }
# {
#     "global_step": 15328,
#     "num_episodes": 36,
#     "rollout/ep_len_mean": 418.6,
#     "rollout/ep_rew_mean": -115.99427795410156,
#     "time/fps": 67,
#     "time/iterations": 36,
#     "time/time_elapsed": 228,
#     "train/baseline": -0.10526532474860917,
#     "train/entropy": 0.00047897821059450507,
#     "train/entropy_loss": -4.789782330760772e-07,
#     "train/grad_norm": 0.00013188139229214357,
#     "train/loss": -5.811681482725817e-07,
#     "train/n_updates": 255,
#     "train/policy_gradient_loss": -1.0218990098564973e-07
# }
# {
#     "global_step": 17428,
#     "num_episodes": 37,
#     "rollout/ep_len_mean": 583.2,
#     "rollout/ep_rew_mean": -102.33370208740234,
#     "time/fps": 67,
#     "time/iterations": 37,
#     "time/time_elapsed": 259,
#     "train/baseline": -0.10488933168313824,
#     "train/entropy": 0.0896181458956562,
#     "train/entropy_loss": -8.961814754826491e-05,
#     "train/grad_norm": 0.06804509268295078,
#     "train/loss": 0.007350937922730338,
#     "train/n_updates": 263,
#     "train/policy_gradient_loss": 0.007440555873316157
# }
# {
#     "global_step": 17930,
#     "num_episodes": 38,
#     "rollout/ep_len_mean": 608.5,
#     "rollout/ep_rew_mean": -102.3333969116211,
#     "time/fps": 66,
#     "time/iterations": 38,
#     "time/time_elapsed": 268,
#     "train/baseline": -0.1023425464119855,
#     "train/entropy": 0.35294600367320306,
#     "train/entropy_loss": -0.0003529460221105899,
#     "train/grad_norm": 3.069495025457758,
#     "train/loss": 0.005012689214764219,
#     "train/n_updates": 296,
#     "train/policy_gradient_loss": 0.0053656347321741505
# }
# {
#     "global_step": 18393,
#     "num_episodes": 39,
#     "rollout/ep_len_mean": 617.6,
#     "rollout/ep_rew_mean": -102.33293151855469,
#     "time/fps": 66,
#     "time/iterations": 39,
#     "time/time_elapsed": 274,
#     "train/baseline": -0.1020412039292607,
#     "train/entropy": 0.05922798183746636,
#     "train/entropy_loss": -5.922798391111428e-05,
#     "train/grad_norm": 0.10826123610604554,
#     "train/loss": 0.007389375880393345,
#     "train/n_updates": 304,
#     "train/policy_gradient_loss": 0.007448604051205621
# }
# {
#     "global_step": 19314,
#     "num_episodes": 41,
#     "rollout/ep_len_mean": 613.1,
#     "rollout/ep_rew_mean": -102.33136749267578,
#     "time/fps": 66,
#     "time/iterations": 41,
#     "time/time_elapsed": 288,
#     "train/baseline": -0.1015617758857188,
#     "train/entropy": 0.051553915720433,
#     "train/entropy_loss": -5.1553918410718325e-05,
#     "train/grad_norm": 0.09261413336207625,
#     "train/loss": 0.006256873937672935,
#     "train/n_updates": 320,
#     "train/policy_gradient_loss": 0.0063084280313887575
# }
# {
#     "global_step": 20318,
#     "num_episodes": 43,
#     "rollout/ep_len_mean": 638.8,
#     "rollout/ep_rew_mean": -102.33140563964844,
#     "time/fps": 66,
#     "time/iterations": 43,
#     "time/time_elapsed": 304,
#     "train/baseline": -0.10147240701920295,
#     "train/entropy": 0.002733463537879288,
#     "train/entropy_loss": -2.7334637309195386e-06,
#     "train/grad_norm": 0.001207943352710572,
#     "train/loss": 4.955061370992553e-06,
#     "train/n_updates": 335,
#     "train/policy_gradient_loss": 7.688525045068673e-06
# }
# {
#     "global_step": 21181,
#     "num_episodes": 45,
#     "rollout/ep_len_mean": 634.3,
#     "rollout/ep_rew_mean": -102.32908630371094,
#     "time/fps": 66,
#     "time/iterations": 45,
#     "time/time_elapsed": 316,
#     "train/baseline": -0.10150320553043829,
#     "train/entropy": 0.0027617329033091664,
#     "train/entropy_loss": -2.761733033670074e-06,
#     "train/grad_norm": 0.0023733681882731616,
#     "train/loss": 1.3957895134808496e-05,
#     "train/n_updates": 349,
#     "train/policy_gradient_loss": 1.6719628092687344e-05
# }
# {
#     "global_step": 22185,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 475.7,
#     "rollout/ep_rew_mean": -115.98948669433594,
#     "time/fps": 66,
#     "time/iterations": 47,
#     "time/time_elapsed": 332,
#     "train/baseline": -0.101041828423395,
#     "train/entropy": 0.002587226073956117,
#     "train/entropy_loss": -2.5872262199300167e-06,
#     "train/grad_norm": 0.001439618148651789,
#     "train/loss": 4.383135092211887e-06,
#     "train/n_updates": 365,
#     "train/policy_gradient_loss": 6.970361425828742e-06
# }
# {
#     "global_step": 23013,
#     "num_episodes": 49,
#     "rollout/ep_len_mean": 462.0,
#     "rollout/ep_rew_mean": -115.9894790649414,
#     "time/fps": 66,
#     "time/iterations": 49,
#     "time/time_elapsed": 344,
#     "train/baseline": -0.10072665627833295,
#     "train/entropy": 0.0024853916450714073,
#     "train/entropy_loss": -2.485391746631649e-06,
#     "train/grad_norm": 0.0015626191404104854,
#     "train/loss": 1.5624538718839176e-05,
#     "train/n_updates": 379,
#     "train/policy_gradient_loss": 1.8109929897036636e-05
# }
# {
#     "global_step": 24017,
#     "num_episodes": 51,
#     "rollout/ep_len_mean": 470.3,
#     "rollout/ep_rew_mean": -115.99090576171875,
#     "time/fps": 66,
#     "time/iterations": 51,
#     "time/time_elapsed": 359,
#     "train/baseline": -0.10033325130993735,
#     "train/entropy": 0.002392116090049967,
#     "train/entropy_loss": -2.3921162153328623e-06,
#     "train/grad_norm": 0.0009127020475716563,
#     "train/loss": 3.4644453705823253e-06,
#     "train/n_updates": 395,
#     "train/policy_gradient_loss": 5.8565616427586065e-06
# }
# {
#     "global_step": 25355,
#     "num_episodes": 54,
#     "rollout/ep_len_mean": 467.6,
#     "rollout/ep_rew_mean": -115.99284362792969,
#     "time/fps": 66,
#     "time/iterations": 54,
#     "time/time_elapsed": 380,
#     "train/baseline": -0.1004385116846992,
#     "train/entropy": 0.010774891765322536,
#     "train/entropy_loss": -1.0774892132303648e-05,
#     "train/grad_norm": 0.268282474595253,
#     "train/loss": -0.018118567282726872,
#     "train/n_updates": 417,
#     "train/policy_gradient_loss": -0.01810779281163377
# }
# {
#     "global_step": 26359,
#     "num_episodes": 56,
#     "rollout/ep_len_mean": 467.6,
#     "rollout/ep_rew_mean": -115.99284362792969,
#     "time/fps": 66,
#     "time/iterations": 56,
#     "time/time_elapsed": 395,
#     "train/baseline": -0.10009134878956259,
#     "train/entropy": 0.005016553390305489,
#     "train/entropy_loss": -5.016553643599764e-06,
#     "train/grad_norm": 0.0021334706398192793,
#     "train/loss": 3.2691399383111275e-06,
#     "train/n_updates": 433,
#     "train/policy_gradient_loss": 8.28569363875431e-06
# }
# {
#     "global_step": 27414,
#     "num_episodes": 58,
#     "rollout/ep_len_mean": 490.3,
#     "rollout/ep_rew_mean": -115.99284362792969,
#     "time/fps": 66,
#     "time/iterations": 58,
#     "time/time_elapsed": 412,
#     "train/baseline": -0.09973942854903566,
#     "train/entropy": 0.004876512361483442,
#     "train/entropy_loss": -4.876512624226355e-06,
#     "train/grad_norm": 0.0015433155349455774,
#     "train/loss": 4.953082578948751e-06,
#     "train/n_updates": 450,
#     "train/policy_gradient_loss": 9.829595001065172e-06
# }
# {
#     "global_step": 28179,
#     "num_episodes": 60,
#     "rollout/ep_len_mean": 466.4,
#     "rollout/ep_rew_mean": -115.9916763305664,
#     "time/fps": 66,
#     "time/iterations": 60,
#     "time/time_elapsed": 423,
#     "train/baseline": -0.09989898056987274,
#     "train/entropy": 0.00010887529351748526,
#     "train/entropy_loss": -1.0887529953151897e-07,
#     "train/grad_norm": 6.837747132522054e-05,
#     "train/loss": 5.331150674692253e-07,
#     "train/n_updates": 463,
#     "train/policy_gradient_loss": 6.419903712640008e-07
# }
# {
#     "global_step": 29145,
#     "num_episodes": 62,
#     "rollout/ep_len_mean": 479.4,
#     "rollout/ep_rew_mean": -115.99169921875,
#     "time/fps": 66,
#     "time/iterations": 62,
#     "time/time_elapsed": 438,
#     "train/baseline": -0.09922368994854001,
#     "train/entropy": 0.00010088940689456649,
#     "train/entropy_loss": -1.0088941149177799e-07,
#     "train/grad_norm": 8.019236918244133e-05,
#     "train/loss": 3.6287107629817683e-07,
#     "train/n_updates": 479,
#     "train/policy_gradient_loss": 4.63760486013598e-07
# }
# {
#     "global_step": 30140,
#     "num_episodes": 64,
#     "rollout/ep_len_mean": 478.5,
#     "rollout/ep_rew_mean": -115.99201965332031,
#     "time/fps": 66,
#     "time/iterations": 64,
#     "time/time_elapsed": 453,
#     "train/baseline": -0.0989591769999655,
#     "train/entropy": 0.00010167568234464852,
#     "train/entropy_loss": -1.0167568653685066e-07,
#     "train/grad_norm": 5.7729208492673934e-05,
#     "train/loss": 1.6506767330781713e-07,
#     "train/n_updates": 495,
#     "train/policy_gradient_loss": 2.6674335273924044e-07
# }
# {
#     "global_step": 31202,
#     "num_episodes": 67,
#     "rollout/ep_len_mean": 426.8,
#     "rollout/ep_rew_mean": -115.9876937866211,
#     "time/fps": 66,
#     "time/iterations": 67,
#     "time/time_elapsed": 469,
#     "train/baseline": -0.0992076684170864,
#     "train/entropy": 0.00010049105094367405,
#     "train/entropy_loss": -1.0049105636511513e-07,
#     "train/grad_norm": 3.953101133902237e-05,
#     "train/loss": 2.0183328519607358e-07,
#     "train/n_updates": 517,
#     "train/policy_gradient_loss": 3.0232433889665344e-07
# }
# {
#     "global_step": 32411,
#     "num_episodes": 70,
#     "rollout/ep_len_mean": 423.2,
#     "rollout/ep_rew_mean": -115.9888916015625,
#     "time/fps": 66,
#     "time/iterations": 70,
#     "time/time_elapsed": 488,
#     "train/baseline": -0.10114627126462597,
#     "train/entropy": 0.00010075991927546315,
#     "train/entropy_loss": -1.0075992459438307e-07,
#     "train/grad_norm": 4.768879859641727e-05,
#     "train/loss": 6.497626766791395e-08,
#     "train/n_updates": 533,
#     "train/policy_gradient_loss": 1.6573619841610464e-07
# }
# {
#     "global_step": 33265,
#     "num_episodes": 72,
#     "rollout/ep_len_mean": 412.0,
#     "rollout/ep_rew_mean": -115.98885345458984,
#     "time/fps": 66,
#     "time/iterations": 72,
#     "time/time_elapsed": 501,
#     "train/baseline": -0.10134594593783565,
#     "train/entropy": 0.00010352415847592056,
#     "train/entropy_loss": -1.0352416405604951e-07,
#     "train/grad_norm": 8.497234117991563e-05,
#     "train/loss": 4.6457194831835597e-07,
#     "train/n_updates": 547,
#     "train/policy_gradient_loss": 5.680961407961149e-07
# }
# {
#     "global_step": 34042,
#     "num_episodes": 74,
#     "rollout/ep_len_mean": 390.2,
#     "rollout/ep_rew_mean": -115.98824310302734,
#     "time/fps": 66,
#     "time/iterations": 74,
#     "time/time_elapsed": 512,
#     "train/baseline": -0.10160798707321142,
#     "train/entropy": 0.000106136329122819,
#     "train/entropy_loss": -1.0613633492084772e-07,
#     "train/grad_norm": 0.00014427566566155292,
#     "train/loss": 1.4819352600170533e-06,
#     "train/n_updates": 560,
#     "train/policy_gradient_loss": 1.5880716205174394e-06
# }
# {
#     "global_step": 35078,
#     "num_episodes": 76,
#     "rollout/ep_len_mean": 411.4,
#     "rollout/ep_rew_mean": -115.99039459228516,
#     "time/fps": 66,
#     "time/iterations": 76,
#     "time/time_elapsed": 528,
#     "train/baseline": -0.10099657900987484,
#     "train/entropy": 9.592314341312481e-05,
#     "train/entropy_loss": -9.592314695636459e-08,
#     "train/grad_norm": 6.569351883930115e-05,
#     "train/loss": 4.364504885895965e-07,
#     "train/n_updates": 577,
#     "train/policy_gradient_loss": 5.323736221245983e-07
# }
# {
#     "global_step": 36082,
#     "num_episodes": 78,
#     "rollout/ep_len_mean": 460.0,
#     "rollout/ep_rew_mean": -115.9925765991211,
#     "time/fps": 66,
#     "time/iterations": 78,
#     "time/time_elapsed": 543,
#     "train/baseline": -0.10073411025814934,
#     "train/entropy": 9.523504922981374e-05,
#     "train/entropy_loss": -9.523505450914627e-08,
#     "train/grad_norm": 5.43232478378286e-05,
#     "train/loss": 2.8273440300097263e-07,
#     "train/n_updates": 593,
#     "train/policy_gradient_loss": 3.779694495165131e-07
# }
# {
#     "global_step": 37329,
#     "num_episodes": 81,
#     "rollout/ep_len_mean": 456.6,
#     "rollout/ep_rew_mean": -115.9925537109375,
#     "time/fps": 66,
#     "time/iterations": 81,
#     "time/time_elapsed": 562,
#     "train/baseline": -0.10097524670668631,
#     "train/entropy": 9.68053985464697e-05,
#     "train/entropy_loss": -9.680540339710812e-08,
#     "train/grad_norm": 5.151381613662428e-05,
#     "train/loss": 4.3998746572052977e-07,
#     "train/n_updates": 613,
#     "train/policy_gradient_loss": 5.367928631964484e-07
# }
# {
#     "global_step": 38175,
#     "num_episodes": 83,
#     "rollout/ep_len_mean": 463.5,
#     "rollout/ep_rew_mean": -115.99134826660156,
#     "time/fps": 66,
#     "time/iterations": 83,
#     "time/time_elapsed": 575,
#     "train/baseline": -0.10115115723119904,
#     "train/entropy": 9.484353601389255e-05,
#     "train/entropy_loss": -9.48435404287314e-08,
#     "train/grad_norm": 6.296913564559266e-05,
#     "train/loss": 2.7460104708628325e-07,
#     "train/n_updates": 627,
#     "train/policy_gradient_loss": 3.6944459225196624e-07
# }
# {
#     "global_step": 39066,
#     "num_episodes": 85,
#     "rollout/ep_len_mean": 449.0,
#     "rollout/ep_rew_mean": -115.9913558959961,
#     "time/fps": 66,
#     "time/iterations": 85,
#     "time/time_elapsed": 590,
#     "train/baseline": -0.10090688044160963,
#     "train/entropy": 9.20189886528533e-05,
#     "train/entropy_loss": -9.201899331401364e-08,
#     "train/grad_norm": 6.065351084316717e-05,
#     "train/loss": 2.6834851674095717e-07,
#     "train/n_updates": 643,
#     "train/policy_gradient_loss": 3.603675153840413e-07
# }
# {
#     "global_step": 40462,
#     "num_episodes": 88,
#     "rollout/ep_len_mean": 438.0,
#     "rollout/ep_rew_mean": -115.99131774902344,
#     "time/fps": 66,
#     "time/iterations": 88,
#     "time/time_elapsed": 611,
#     "train/baseline": -0.10093940361461853,
#     "train/entropy": 9.061495711648604e-05,
#     "train/entropy_loss": -9.06149617563301e-08,
#     "train/grad_norm": 3.05705788719024e-05,
#     "train/loss": 2.2212161709944667e-07,
#     "train/n_updates": 665,
#     "train/policy_gradient_loss": 3.1273657441488467e-07
# }
# {
#     "global_step": 41466,
#     "num_episodes": 90,
#     "rollout/ep_len_mean": 463.9,
#     "rollout/ep_rew_mean": -115.9913558959961,
#     "time/fps": 66,
#     "time/iterations": 90,
#     "time/time_elapsed": 626,
#     "train/baseline": -0.10071360874841234,
#     "train/entropy": 8.958688704296947e-05,
#     "train/entropy_loss": -8.958689168281353e-08,
#     "train/grad_norm": 5.39318575647485e-05,
#     "train/loss": 2.139449915006253e-07,
#     "train/n_updates": 681,
#     "train/policy_gradient_loss": 3.0353188407161724e-07
# }
# {
#     "global_step": 42286,
#     "num_episodes": 92,
#     "rollout/ep_len_mean": 461.3,
#     "rollout/ep_rew_mean": -115.99139404296875,
#     "time/fps": 66,
#     "time/iterations": 92,
#     "time/time_elapsed": 639,
#     "train/baseline": -0.10020668122351954,
#     "train/entropy": 8.910692213248694e-05,
#     "train/entropy_loss": -8.91069253938781e-08,
#     "train/grad_norm": 5.1185441066081694e-05,
#     "train/loss": 4.5088699618389683e-07,
#     "train/n_updates": 697,
#     "train/policy_gradient_loss": 5.399939198014181e-07
# }
# {
#     "global_step": 43346,
#     "num_episodes": 94,
#     "rollout/ep_len_mean": 466.9,
#     "rollout/ep_rew_mean": -115.98939514160156,
#     "time/fps": 66,
#     "time/iterations": 94,
#     "time/time_elapsed": 655,
#     "train/baseline": -0.10029335486589792,
#     "train/entropy": 8.766217901471205e-05,
#     "train/entropy_loss": -8.766218278261867e-08,
#     "train/grad_norm": 6.217706036945206e-05,
#     "train/loss": 4.499706095982349e-07,
#     "train/n_updates": 710,
#     "train/policy_gradient_loss": 5.376327903507314e-07
# }
# {
#     "global_step": 44117,
#     "num_episodes": 96,
#     "rollout/ep_len_mean": 465.9,
#     "rollout/ep_rew_mean": -115.98797607421875,
#     "time/fps": 66,
#     "time/iterations": 96,
#     "time/time_elapsed": 667,
#     "train/baseline": -0.10004176470709768,
#     "train/entropy": 8.66451637193677e-05,
#     "train/entropy_loss": -8.66451674852442e-08,
#     "train/grad_norm": 8.353118589354835e-05,
#     "train/loss": 1.6044234207868158e-07,
#     "train/n_updates": 728,
#     "train/policy_gradient_loss": 2.470875060112121e-07
# }
# {
#     "global_step": 45006,
#     "num_episodes": 98,
#     "rollout/ep_len_mean": 454.4,
#     "rollout/ep_rew_mean": -115.9850082397461,
#     "time/fps": 66,
#     "time/iterations": 98,
#     "time/time_elapsed": 680,
#     "train/baseline": -0.10060337520439705,
#     "train/entropy": 8.505405276082456e-05,
#     "train/entropy_loss": -8.505405713066239e-08,
#     "train/grad_norm": 5.474833005791879e-05,
#     "train/loss": 2.2768597229827492e-07,
#     "train/n_updates": 741,
#     "train/policy_gradient_loss": 3.1274002765258047e-07
# }
# C:\Users\skfim\AppData\Local\Temp\ipykernel_21864\1280940290.py:41: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\ReduceOps.cpp:1823.)
#   returns_std = returns.std()
# {
#     "global_step": 46405,
#     "num_episodes": 101,
#     "rollout/ep_len_mean": 447.7,
#     "rollout/ep_rew_mean": -115.98465728759766,
#     "time/fps": 66,
#     "time/iterations": 101,
#     "time/time_elapsed": 701,
#     "train/baseline": -0.10024127166572924,
#     "train/entropy": 8.438679651590064e-05,
#     "train/entropy_loss": -8.438680065836479e-08,
#     "train/grad_norm": 2.6298381840206275e-05,
#     "train/loss": 1.8939292623088022e-07,
#     "train/n_updates": 763,
#     "train/policy_gradient_loss": 2.7377972422470975e-07
# }
# {
#     "global_step": 47130,
#     "num_episodes": 103,
#     "rollout/ep_len_mean": 442.2,
#     "rollout/ep_rew_mean": -115.98690032958984,
#     "time/fps": 66,
#     "time/iterations": 103,
#     "time/time_elapsed": 712,
#     "train/baseline": -0.10115742635921868,
#     "train/entropy": 9.23357602005126e-05,
#     "train/entropy_loss": -9.233576392375653e-08,
#     "train/grad_norm": 0.00012883133422292303,
#     "train/loss": 1.2725777622790702e-06,
#     "train/n_updates": 775,
#     "train/policy_gradient_loss": 1.3649135155446857e-06
# }
# {
#     "global_step": 48134,
#     "num_episodes": 105,
#     "rollout/ep_len_mean": 428.6,
#     "rollout/ep_rew_mean": -115.98661804199219,
#     "time/fps": 66,
#     "time/iterations": 105,
#     "time/time_elapsed": 727,
#     "train/baseline": -0.10096000531516529,
#     "train/entropy": 8.155487466865452e-05,
#     "train/entropy_loss": -8.155487840610931e-08,
#     "train/grad_norm": 3.9251104198001485e-05,
#     "train/loss": 1.3669181342379488e-07,
#     "train/n_updates": 791,
#     "train/policy_gradient_loss": 2.1824669360626103e-07
# }
# {
#     "global_step": 49067,
#     "num_episodes": 107,
#     "rollout/ep_len_mean": 444.8,
#     "rollout/ep_rew_mean": -115.988525390625,
#     "time/fps": 66,
#     "time/iterations": 107,
#     "time/time_elapsed": 741,
#     "train/baseline": -0.10087340823214386,
#     "train/entropy": 8.125556321049641e-05,
#     "train/entropy_loss": -8.125556811527141e-08,
#     "train/grad_norm": 4.6156345108881525e-05,
#     "train/loss": 2.0778021995023925e-07,
#     "train/n_updates": 806,
#     "train/policy_gradient_loss": 2.8903578400526643e-07
# }
# {
#     "global_step": 50053,
#     "num_episodes": 109,
#     "rollout/ep_len_mean": 466.2,
#     "rollout/ep_rew_mean": -115.9917984008789,
#     "time/fps": 66,
#     "time/iterations": 109,
#     "time/time_elapsed": 756,
#     "train/baseline": -0.10063634813299933,
#     "train/entropy": 8.115517630358227e-05,
#     "train/entropy_loss": -8.115517946549744e-08,
#     "train/grad_norm": 7.007837075434509e-05,
#     "train/loss": 1.649686875992984e-07,
#     "train/n_updates": 822,
#     "train/policy_gradient_loss": 2.461238697293311e-07
# }
# Задача не решена за 50000 шагов
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>num_episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▂▃▃▃▂▁▁▂▂▂▂▂▂▆▇▇██▃▃▃▄▃▄▃▂▂▁▂▃▃▃▂▃▃▃▃▃▂▃</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁█████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>▁▅▅▅██████████▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>time/iterations</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>time/time_elapsed</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/baseline</td><td>▂▆█▇▅▂▁▂▃▄▃▂▃▃▅▆▆▆▆▇▇▇▇▇██▆▆▆▇▆▆▆▇▇▇▇▆▆▇</td></tr><tr><td>train/entropy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▃█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>████████████▆▁▇█████████████████████████</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▆▆▆▆▆▆▆▆▆▆▆█▇██▆▆▆▆▁▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>train/n_updates</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁█▆▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>50053</td></tr><tr><td>num_episodes</td><td>109</td></tr><tr><td>rollout/ep_len_mean</td><td>466.2</td></tr><tr><td>rollout/ep_rew_mean</td><td>-115.9918</td></tr><tr><td>time/fps</td><td>66</td></tr><tr><td>time/iterations</td><td>109</td></tr><tr><td>time/time_elapsed</td><td>756</td></tr><tr><td>train/baseline</td><td>-0.10064</td></tr><tr><td>train/entropy</td><td>8e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>7e-05</td></tr><tr><td>train/loss</td><td>0.0</td></tr><tr><td>train/n_updates</td><td>822</td></tr><tr><td>train/policy_gradient_loss</td><td>0.0</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync c:\Users\skfim\RL\RL25\practices\prac5\wandb\offline-run-20251101_190759-2b6vh69t<code>
# Find logs at: <code>.\wandb\offline-run-20251101_190759-2b6vh69t\logs</code>

# %% [markdown]
# ### Две эпохи обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=2),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-2'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,)
)
# Out:
# C:\Users\skfim\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\vizdoom\gymnasium_wrapper\base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cuda device
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 run_algorithm(
#       2     algorithm_class=BatchedAverageReturnReinforce,
#       3     algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=2),
#       4     use_wandb=True,
#       5     wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-2'),
#       6     learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
#       7                     save_checkpoint_path='/content/drive/My Drive/seminar_actor-critic/reinforce_batch-epoch-2')
#       8 )
#
# Cell In[8], line 15, in run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs)
#      11         wandb.finish()
#      13     wandb.init(**wandb_kwargs)
# ---> 15 model.learn(**learn_kwargs)
#      16 if use_wandb:
#      17     wandb.finish()
#
# Cell In[7], line 179, in Reinforce.learn(self, max_timesteps, expected_return, log_interval, save_checkpoint_path, save_checkpoint_interval)
#     177 self._num_timesteps_at_start = 0
#     178 log_interval = log_interval or math.inf
# --> 179 if save_checkpoint_path is None or save_checkpoint_interval is None or not COLAB:
#     180     save_checkpoint_interval = math.inf
#     182 next_log_step = self.num_timesteps + log_interval
#
# NameError: name 'COLAB' is not defined
